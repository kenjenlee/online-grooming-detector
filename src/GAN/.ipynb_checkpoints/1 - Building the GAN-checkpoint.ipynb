# %% [markdown]
# https://github.com/aymericdamien/TensorFlow-Examples/blob/master/examples/3_NeuralNetworks/gan.py
# https://stackoverflow.com/questions/40994583/how-to-implement-tensorflows-next-batch-for-own-data

# %%
import xml.etree.ElementTree as ET
import csv


def get_labels_dict(data_path):
    labels_dict = {}
    with open(data_path + 'sci_labels.csv', 'r') as f:
        file = csv.reader(f)
        for row in file:
            labels_dict[row[0]] = row[1]
    return labels_dict


def get_features_labels(root, labels_dict):
    corpus = [] # each row is a string formed from all messages in a conversations
    labels = [] # each row is 0 or 1, corresponds to label for same row in corpus

    for conversation in root:
        string = " "
        for message in conversation:
            text = message.find('text').text
            if text is not None:
                string = string + "\r\n" + text 
        corpus.append(string)
        labels.append(int(labels_dict[conversation.get('id')]))
    return corpus, labels

# %%
train_data_path = '../../data/svm_training_data/'
training_xml = ET.parse(train_data_path + 'training_data.xml')
train_root = training_xml.getroot()

test_data_path = '../../data/svm_test_data/'
test_data_src = '../../data/pan12-sexual-predator-identification-test-corpus-2012-05-21/'
test_xml = ET.parse(test_data_src + 'pan12-sexual-predator-identification-test-corpus-2012-05-17.xml')
test_root = test_xml.getroot()

train_corpus, train_labels = get_features_labels(train_root, get_labels_dict(train_data_path))
test_corpus, test_labels = get_features_labels(test_root, get_labels_dict(test_data_path))

train_corpus_norm = []
train_corpus_susp = []
train_labels_norm = []
train_labels_susp = []
for index in range(len(train_corpus)):
    if train_labels[index] == 1:
        train_corpus_susp.append(train_corpus[index])
        train_labels_susp.append(train_labels[index])
    else:
        train_corpus_norm.append(train_corpus[index])
        train_labels_norm.append(train_labels[index])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MaxAbsScaler
import scipy
# from sklearn.model_selection import train_test_split
import numpy as np

print('TODO: PLEASE REMOVE LIMITATION OF FIRST 1000 TEST CASES DONE DUE TO MEMORY ISSUES')

vectorizer = TfidfVectorizer()
_ = vectorizer.fit_transform(train_corpus)
X_train_norm = vectorizer.transform(train_corpus_norm)
X_train_susp = vectorizer.transform(train_corpus_susp)
# limiting to 1000 test cases due to memory issues
X_test = vectorizer.transform(test_corpus[:1000])

X_train_norm = scipy.sparse.csr_matrix(X_train_norm, dtype=np.float32)
y_train_norm = np.array(train_labels_norm)
X_train_susp = scipy.sparse.csr_matrix(X_train_susp, dtype=np.float32)
y_train_susp = np.array(train_labels_susp)
X_test = scipy.sparse.csr_matrix(X_test, dtype=np.float32)
y_test = np.array(test_labels[:1000])

print(np.min(X_train_norm[:][0]))
print(np.max(X_train_norm[:][0]))

scaler = MaxAbsScaler()
X_train_norm = scaler.fit_transform(X_train_norm)
X_train_susp = scaler.fit_transform(X_train_susp)
X_test = scaler.fit_transform(X_test)
X_train_norm.data -= 0.5
X_train_susp.data -= 0.5
X_test.data -= 0.5
X_train_norm.data *= 2
X_train_susp.data *= 2
X_test.data *= 2

print(np.min(X_train_norm[:][0]))
print(np.max(X_train_norm[:][0]))

# X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.3, random_state=87)
# print("Train data shape:{}\r\nTest data shape:{}".format(X_train.shape, X_test.shape))
# Out:
# TODO: PLEASE REMOVE LIMITATION OF FIRST 1000 TEST CASES DONE DUE TO MEMORY ISSUES
# 0.0
# 0.44709805
# -0.96498847
# 1.0

# %%
# print(X_train_norm[:][0])
print(np.mean(X_train_norm[:][0]))
# Out:
# -0.0010184544

# %%
""" Generative Adversarial Networks (GAN).
Using generative adversarial networks (GAN) to generate digit images from a
noise distribution.
References:
    - Generative adversarial nets. I Goodfellow, J Pouget-Abadie, M Mirza,
    B Xu, D Warde-Farley, S Ozair, Y. Bengio. Advances in neural information
    processing systems, 2672-2680.
    - Understanding the difficulty of training deep feedforward neural networks.
    X Glorot, Y Bengio. Aistats 9, 249-256
Links:
    - [GAN Paper](https://arxiv.org/pdf/1406.2661.pdf).
    - [MNIST Dataset](http://yann.lecun.com/exdb/mnist/).
    - [Xavier Glorot Init](www.cs.cmu.edu/~bhiksha/courses/deeplearning/Fall.../AISTATS2010_Glorot.pdf).
Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
"""

from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Import MNIST data
# from tensorflow.examples.tutorials.mnist import input_data
# mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Training Params
num_steps = 10
batch_size = 100 #128
learning_rate = 0.0002

# Network Params
image_dim = X_train_norm.shape[1] #784 # 28*28 pixels
gen_hidden_dim = 10 #256
gen_hidden_dim2 = 10
disc_hidden_dim = 10 #256
noise_dim = X_train_norm.shape[1] # 100 # Noise data points
print(X_train_norm.shape[1])

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.))

# Store layers weight & bias
weights = {
    'gen_hidden1': tf.Variable(glorot_init([noise_dim, gen_hidden_dim])),
    'gen_hidden2': tf.Variable(glorot_init([gen_hidden_dim, gen_hidden_dim2])),
    'gen_out': tf.Variable(glorot_init([gen_hidden_dim, image_dim])),
    'disc1_hidden1': tf.Variable(glorot_init([image_dim, disc_hidden_dim])),
    'disc1_out': tf.Variable(glorot_init([disc_hidden_dim, 1])),
    'disc2_hidden1': tf.Variable(glorot_init([image_dim, disc_hidden_dim])),
    'disc2_out': tf.Variable(glorot_init([disc_hidden_dim, 1])),
}
biases = {
    'gen_hidden1': tf.Variable(tf.zeros([gen_hidden_dim])),
    'gen_hidden2': tf.Variable(tf.zeros([gen_hidden_dim2])),
    'gen_out': tf.Variable(tf.zeros([image_dim])),
    'disc1_hidden1': tf.Variable(tf.zeros([disc_hidden_dim])),
    'disc1_out': tf.Variable(tf.zeros([1])),
    'disc2_hidden1': tf.Variable(tf.zeros([disc_hidden_dim])),
    'disc2_out': tf.Variable(tf.zeros([1])),
}


# Generator
def generator(x):
    hidden_layer = tf.matmul(x, weights['gen_hidden1'])
    hidden_layer = tf.add(hidden_layer, biases['gen_hidden1'])
    hidden_layer = tf.nn.leaky_relu(hidden_layer)
    hidden_layer2 = tf.matmul(hidden_layer, weights['gen_hidden2'])
    hidden_layer2 = tf.add(hidden_layer2, biases['gen_hidden2'])
    hidden_layer2 = tf.nn.leaky_relu(hidden_layer2)
    out_layer = tf.matmul(hidden_layer2, weights['gen_out'])
#     out_layer = tf.matmul(hidden_layer, weights['gen_out'])
    out_layer = tf.add(out_layer, biases['gen_out'])
    out_layer = tf.nn.tanh(out_layer)
    return out_layer


# Discriminator
def discriminator_SCI(x, reuse=False): # is D in paper
#     https://mlnotebook.github.io/post/GAN4/
    with tf.variable_scope("disc_SCI") as scope:
        if reuse:
            scope.reuse_variables()
        hidden_layer = tf.matmul(x, weights['disc1_hidden1'])
        hidden_layer = tf.add(hidden_layer, biases['disc1_hidden1'])
        hidden_layer = tf.nn.relu(hidden_layer)
        out_layer = tf.matmul(hidden_layer, weights['disc1_out'])
        out_layer = tf.add(out_layer, biases['disc1_out'])
        out_layer = tf.nn.sigmoid(out_layer)
        return out_layer

def discriminator_gvr(x, reuse=False): # is D prime in paper, discriminator_generated_vs_real
    with tf.variable_scope("disc_gvr") as scope:
        if reuse:
            scope.reuse_variables()
        hidden_layer = tf.matmul(x, weights['disc2_hidden1'])
        hidden_layer = tf.add(hidden_layer, biases['disc2_hidden1'])
        hidden_layer = tf.nn.relu(hidden_layer)
        out_layer = tf.matmul(hidden_layer, weights['disc2_out'])
        out_layer = tf.add(out_layer, biases['disc2_out'])
        out_layer = tf.nn.sigmoid(out_layer)
        return out_layer

def next_batch(num, data, labels):
    '''
    Return a total of `num` random samples and labels. 
    '''
    idx = np.arange(0 , data.shape[0])
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i].toarray() for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    data_shuffle = scipy.sparse.csr_matrix(data_shuffle)
    print(data_shuffle.shape)
    return data_shuffle, labels_shuffle
#     print(len(data_shuffle[0]))
#     return scipy.sparse.csr_matrix(data_shuffle), np.asarray(labels_shuffle)
#     return np.asarray(data_shuffle), np.asarray(labels_shuffle)

# https://stackoverflow.com/questions/40896157/scipy-sparse-csr-matrix-to-tensorflow-sparsetensor-mini-batch-gradient-descent
def convert_sparse_matrix_to_sparse_tensor(X):
    coo = X.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)
# Out:
# 121394

# %%
# Build Networks
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
# disc_input_normal = tf.placeholder(tf.float32, shape=[None, image_dim], name='disc_input_normal')
# disc_input_real_susp = tf.placeholder(tf.float32, shape=[None, image_dim], name='disc_input_real_susp')
# # disc_input_fake_susp = tf.placeholder(tf.float32, shape=[None, image_dim], name='disc_input_fake_susp')

# tf.float32
# https://towardsdatascience.com/how-to-use-dataset-in-tensorflow-c758ef9e4428
# x_norm = tf.sparse_placeholder(tf.float64)
# x_susp = tf.sparse_placeholder(tf.float64)
x_norm, x_susp = tf.placeholder(tf.float32, shape=[None, image_dim]), tf.placeholder(tf.float32, shape=[None, image_dim])
dataset_norm = tf.data.Dataset.from_tensor_slices(x_norm).repeat().batch(batch_size)
dataset_susp = tf.data.Dataset.from_tensor_slices(x_susp).repeat().batch(batch_size)
# train_data = (np.random.sample((100,2)), np.random.sample((100,1)))
# test_data = (np.array([[1,2]]), np.array([[0]]))
iter_norm = dataset_norm.make_initializable_iterator()
iter_susp = dataset_susp.make_initializable_iterator()
features_norm = iter_norm.get_next()
features_susp = iter_susp.get_next()

# Build Generator Network
# gen_sample_pre = generator(features_susp)
# gen_sample_pre = generator(gen_input)
gen_sample = generator(gen_input)

# Build 2 Discriminator Networks (one from noise input, one from generated samples)
# disc_SCI_normal = discriminator_SCI(disc_input_normal)
# disc_SCI_susp_real = discriminator_SCI(disc_input_real_susp)
# disc_SCI_susp_fake = discriminator_SCI(gen_sample)
# disc_gvr_real = discriminator_gvr(disc_input_real_susp)
# disc_gvr_fake = discriminator_gvr(gen_sample)

disc_SCI_normal = discriminator_SCI(features_norm)
disc_SCI_susp_real = discriminator_SCI(features_susp)
disc_SCI_susp_fake = discriminator_SCI(gen_sample, reuse=True)
disc_gvr_real = discriminator_gvr(features_susp)
disc_gvr_fake = discriminator_gvr(gen_sample, reuse=True)


# Build Loss
gen_loss_pre = tf.losses.mean_squared_error(features_susp, gen_sample)
# gen_loss = -tf.reduce_mean(tf.log(disc_SCI_susp_fake + 1e-8) + tf.log(disc_gvr_fake + 1e-8))
gen_loss = -tf.reduce_mean(tf.log(disc_gvr_fake + 1e-8))
disc_SCI_loss = -tf.reduce_mean(tf.log(disc_SCI_normal + 1e-8) + tf.log(1. - disc_SCI_susp_real + 1e-8) + tf.log(1. - disc_SCI_susp_fake + 1e-8))
disc_SCI_loss_pre = -tf.reduce_mean(tf.log(disc_SCI_normal + 1e-8) + tf.log(1. - disc_SCI_susp_real + 1e-8))
disc_gvr_loss = -tf.reduce_mean(tf.log(disc_gvr_real + 1e-8) + tf.log(1. - disc_gvr_fake + 1e-8))

# https://blog.paperspace.com/implementing-gans-in-tensorflow/
# disc_gvr_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_real,labels=tf.ones_like(disc_gvr_real)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_fake,labels=tf.zeros_like(disc_gvr_fake)))
# gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_fake,labels=tf.ones_like(disc_gvr_fake)))
# disc_SCI_loss_pre = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_normal,labels=tf.ones_like(disc_SCI_normal)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_real,labels=tf.zeros_like(disc_SCI_susp_real)))
# disc_SCI_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_normal,labels=tf.ones_like(disc_SCI_normal)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_real,labels=tf.zeros_like(disc_SCI_susp_real)) + \
#                               tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_fake,labels=tf.zeros_like(disc_SCI_susp_fake)))
# experimenting with flipping the labels
# disc_gvr_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_real,labels=tf.zeros_like(disc_gvr_real)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_fake,labels=tf.ones_like(disc_gvr_fake)))
# gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_gvr_fake,labels=tf.zeros_like(disc_gvr_fake)))
# disc_SCI_loss_pre = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_normal,labels=tf.zeros_like(disc_SCI_normal)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_real,labels=tf.ones_like(disc_SCI_susp_real)))
# disc_SCI_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_normal,labels=tf.zeros_like(disc_SCI_normal)) +\
#                            tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_real,labels=tf.ones_like(disc_SCI_susp_real)) + \
#                               tf.nn.sigmoid_cross_entropy_with_logits(logits=disc_SCI_susp_fake,labels=tf.ones_like(disc_SCI_susp_fake)))


# Build Optimizers
# optimizer_gen_pre = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer_gen = tf.train.AdamOptimizer(learning_rate=learning_rate*10)
optimizer_disc_SCI = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer_disc_gvr = tf.train.AdamOptimizer(learning_rate=learning_rate)

# Training Variables for each optimizer
# By default in TensorFlow, all variables are updated by each optimizer, so we
# need to precise for each one of them the specific variables to update.
# Generator Network Variables
gen_vars = [weights['gen_hidden1'], weights['gen_out'],
            biases['gen_hidden1'], biases['gen_out']]
# Discriminator Network Variables
disc_SCI_vars = [weights['disc1_hidden1'], weights['disc1_out'],
            biases['disc1_hidden1'], biases['disc1_out']]
disc_gvr_vars = [weights['disc2_hidden1'], weights['disc2_out'],
            biases['disc2_hidden1'], biases['disc2_out']]

# Create training operations
train_gen_pre = optimizer_gen.minimize(gen_loss_pre, var_list=gen_vars)
train_gen = optimizer_gen.minimize(gen_loss, var_list=gen_vars)
train_disc_SCI = optimizer_disc_SCI.minimize(disc_SCI_loss, var_list=disc_SCI_vars)
train_disc_gvr = optimizer_disc_gvr.minimize(disc_gvr_loss, var_list=disc_gvr_vars)

print(X_train_norm.shape)
print(X_train_susp.shape)
# Out:
# (13802, 121394)
# (901, 121394)

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)
    print('Initializing dataset pipeline variables')
    sess.run([iter_norm.initializer, iter_susp.initializer], feed_dict={ x_norm: X_train_norm.todense(), x_susp: X_train_susp.todense()})
    
#     print('Pretraining of generator starting.')
#     for i in range(1, num_steps*100+1):
#         z = np.random.uniform(-1., 1., size=[batch_size, noise_dim])
#         feed_dict = {gen_input: z}
#         _, glpre = sess.run([train_gen_pre, gen_loss_pre], feed_dict=feed_dict)
#         print('Step %i: Generator Loss: %f' % (i, glpre))
        
    print('Pretraining of generator and disc_gvr starting.')
    for i in range(1, num_steps*100+1):
        z = np.random.uniform(-1., 1., size=[batch_size, noise_dim])
        feed_dict = {gen_input: z}
        _, _, gl, dgvrl = sess.run([train_gen, train_disc_gvr, gen_loss, disc_gvr_loss], feed_dict=feed_dict)
        _, gl = sess.run([train_gen, gen_loss], feed_dict=feed_dict)
        print('Step %i: Generator Loss: %f, Disc gvr Loss: %f' % (i, gl, dgvrl))
    
    
    print('Starting actual training')
    for i in range(1, num_steps+1):
        # Generate noise to feed to the generator
        z = np.random.uniform(-1., 1., size=[batch_size, noise_dim])
        # Train
#         feed_dict = {disc_input: batch_x, gen_input: z}
        feed_dict = {gen_input: z}
        _, _, _, gl, dSCIl, dgvrl = sess.run([train_gen, train_disc_SCI, train_disc_gvr, gen_loss, disc_SCI_loss, disc_gvr_loss],
                                feed_dict=feed_dict)
#         if i % 1000 == 0 or i == 1:
        print('Step %i: Generator Loss: %f, Disc SCI Loss: %f, Disc gvr Loss: %f' % (i, gl, dSCIl, dgvrl))

    print("Finished Training")
    # test SCI
    sess.run(iter_norm.initializer, feed_dict={ x_norm: X_test.todense()})
    y_pred = sess.run(disc_SCI_normal)
    print(metrics.accuracy_score(y_test, y_pred))
#     # Generate images from noise, using the generator network.
#     f, a = plt.subplots(4, 10, figsize=(10, 4))
#     for i in range(10):
#         # Noise input.
#         z = np.random.uniform(-1., 1., size=[4, noise_dim])
#         g = sess.run([gen_sample], feed_dict={gen_input: z})
#         g = np.reshape(g, newshape=(4, 28, 28, 1))
#         # Reverse colours for better display
#         g = -1 * (g - 1)
#         for j in range(4):
#             # Generate image from noise. Extend to 3 channels for matplot figure.
#             img = np.reshape(np.repeat(g[j][:, :, np.newaxis], 3, axis=2),
#                              newshape=(28, 28, 3))
#             a[j][i].imshow(img)

#     f.show()
#     plt.draw()
#     plt.waitforbuttonpress()
# Out:
# Initializing dataset pipeline variables
# Pretraining of generator and disc_gvr starting.
# Step 1: Generator Loss: 5.873748, Disc gvr Loss: 1.842736
# Step 2: Generator Loss: 1.518520, Disc gvr Loss: 0.974840
# Step 3: Generator Loss: 3.434498, Disc gvr Loss: 0.919637
# Step 4: Generator Loss: 4.387540, Disc gvr Loss: 1.805897
# Step 5: Generator Loss: 5.625593, Disc gvr Loss: 1.444345
# Step 6: Generator Loss: 5.576671, Disc gvr Loss: 1.725397
# Step 7: Generator Loss: 7.030046, Disc gvr Loss: 1.474641
# Step 8: Generator Loss: 7.192285, Disc gvr Loss: 1.204069
# Step 9: Generator Loss: 8.571954, Disc gvr Loss: 1.048688
# Step 10: Generator Loss: 8.699199, Disc gvr Loss: 1.175761
# Step 11: Generator Loss: 6.249257, Disc gvr Loss: 1.671360
# Step 12: Generator Loss: 7.838841, Disc gvr Loss: 0.816590
# Step 13: Generator Loss: 6.538655, Disc gvr Loss: 1.158683
# Step 14: Generator Loss: 7.596888, Disc gvr Loss: 2.082280
# Step 15: Generator Loss: 7.974888, Disc gvr Loss: 1.171519
# Step 16: Generator Loss: 8.505017, Disc gvr Loss: 1.252745
# Step 17: Generator Loss: 7.542907, Disc gvr Loss: 2.604579
# Step 18: Generator Loss: 10.233655, Disc gvr Loss: 1.674041
# Step 19: Generator Loss: 8.137026, Disc gvr Loss: 1.289497
# Step 20: Generator Loss: 9.685927, Disc gvr Loss: 0.857384
# Step 21: Generator Loss: 9.029119, Disc gvr Loss: 0.950586
# Step 22: Generator Loss: 9.280109, Disc gvr Loss: 0.649840
# Step 23: Generator Loss: 10.504875, Disc gvr Loss: 0.678552
# Step 24: Generator Loss: 9.601364, Disc gvr Loss: 1.222538
# Step 25: Generator Loss: 9.893896, Disc gvr Loss: 0.907636
# Step 26: Generator Loss: 9.520786, Disc gvr Loss: 1.172783
# Step 27: Generator Loss: 9.347158, Disc gvr Loss: 0.984113
# Step 28: Generator Loss: 9.916554, Disc gvr Loss: 1.463724
# Step 29: Generator Loss: 10.052471, Disc gvr Loss: 0.878820
# Step 30: Generator Loss: 9.667710, Disc gvr Loss: 1.096182
# Step 31: Generator Loss: 8.936441, Disc gvr Loss: 1.244689
# Step 32: Generator Loss: 8.580440, Disc gvr Loss: 1.568481
# Step 33: Generator Loss: 9.006018, Disc gvr Loss: 0.791224
# Step 34: Generator Loss: 7.212447, Disc gvr Loss: 1.865249
# Step 35: Generator Loss: 9.043009, Disc gvr Loss: 0.524856
# Step 36: Generator Loss: 8.602432, Disc gvr Loss: 0.708938
# Step 37: Generator Loss: 8.606217, Disc gvr Loss: 0.834564
# Step 38: Generator Loss: 6.703557, Disc gvr Loss: 0.961675
# Step 39: Generator Loss: 8.586914, Disc gvr Loss: 0.643485
# Step 40: Generator Loss: 7.430220, Disc gvr Loss: 0.821405
# Step 41: Generator Loss: 7.613565, Disc gvr Loss: 0.483386
# Step 42: Generator Loss: 6.462486, Disc gvr Loss: 0.890918
# Step 43: Generator Loss: 7.698138, Disc gvr Loss: 0.555216
# Step 44: Generator Loss: 7.144462, Disc gvr Loss: 0.595574
# Step 45: Generator Loss: 7.159103, Disc gvr Loss: 0.720486
# Step 46: Generator Loss: 6.843023, Disc gvr Loss: 0.744805
# Step 47: Generator Loss: 7.242877, Disc gvr Loss: 0.762627
# Step 48: Generator Loss: 8.001645, Disc gvr Loss: 0.757106
# Step 49: Generator Loss: 7.700955, Disc gvr Loss: 0.764050
# Step 50: Generator Loss: 8.115900, Disc gvr Loss: 0.999611
# Step 51: Generator Loss: 7.703814, Disc gvr Loss: 0.621289
# Step 52: Generator Loss: 7.560499, Disc gvr Loss: 0.643679
# Step 53: Generator Loss: 10.028730, Disc gvr Loss: 0.719077
# Step 54: Generator Loss: 9.005516, Disc gvr Loss: 0.969627
# Step 55: Generator Loss: 9.055017, Disc gvr Loss: 0.658849
# Step 56: Generator Loss: 7.467275, Disc gvr Loss: 1.025523
# Step 57: Generator Loss: 7.962954, Disc gvr Loss: 0.728275
# Step 58: Generator Loss: 9.095616, Disc gvr Loss: 0.760676
# Step 59: Generator Loss: 11.061221, Disc gvr Loss: 0.394370
# Step 60: Generator Loss: 8.900927, Disc gvr Loss: 0.836356
# Step 61: Generator Loss: 9.552625, Disc gvr Loss: 0.626318
# Step 62: Generator Loss: 8.848056, Disc gvr Loss: 0.413711
# Step 63: Generator Loss: 7.645157, Disc gvr Loss: 0.845005
# Step 64: Generator Loss: 8.831651, Disc gvr Loss: 0.395923
# Step 65: Generator Loss: 8.032247, Disc gvr Loss: 0.771069
# Step 66: Generator Loss: 8.888873, Disc gvr Loss: 0.428074
# Step 67: Generator Loss: 9.831175, Disc gvr Loss: 0.590528
# Step 68: Generator Loss: 8.571880, Disc gvr Loss: 0.914336
# Step 69: Generator Loss: 9.295846, Disc gvr Loss: 0.493698
# Step 70: Generator Loss: 9.534469, Disc gvr Loss: 0.355062
# Step 71: Generator Loss: 9.621897, Disc gvr Loss: 0.333907
# Step 72: Generator Loss: 8.046111, Disc gvr Loss: 0.661451
# Step 73: Generator Loss: 10.062030, Disc gvr Loss: 0.587681
# Step 74: Generator Loss: 9.816874, Disc gvr Loss: 0.527578
# Step 75: Generator Loss: 9.290208, Disc gvr Loss: 0.517448
# Step 76: Generator Loss: 10.105670, Disc gvr Loss: 0.334117
# Step 77: Generator Loss: 9.324519, Disc gvr Loss: 0.415451
# Step 78: Generator Loss: 8.808556, Disc gvr Loss: 0.523080
# Step 79: Generator Loss: 8.663230, Disc gvr Loss: 0.787830
# Step 80: Generator Loss: 9.099998, Disc gvr Loss: 0.483823
# Step 81: Generator Loss: 7.899449, Disc gvr Loss: 0.687540
# Step 82: Generator Loss: 8.462617, Disc gvr Loss: 0.644987
# Step 83: Generator Loss: 8.977828, Disc gvr Loss: 0.318068
# Step 84: Generator Loss: 8.491383, Disc gvr Loss: 0.314245
# Step 85: Generator Loss: 9.123315, Disc gvr Loss: 0.581616
# Step 86: Generator Loss: 7.892983, Disc gvr Loss: 0.652742
# Step 87: Generator Loss: 8.242025, Disc gvr Loss: 0.348435
# Step 88: Generator Loss: 9.660635, Disc gvr Loss: 0.640665
# Step 89: Generator Loss: 10.896803, Disc gvr Loss: 0.393934
# Step 90: Generator Loss: 9.346839, Disc gvr Loss: 0.369945
# Step 91: Generator Loss: 8.894996, Disc gvr Loss: 0.748443
# Step 92: Generator Loss: 9.180887, Disc gvr Loss: 0.575989
# Step 93: Generator Loss: 8.798649, Disc gvr Loss: 0.316554
# Step 94: Generator Loss: 9.586399, Disc gvr Loss: 0.540668
# Step 95: Generator Loss: 8.847519, Disc gvr Loss: 0.252449
# Step 96: Generator Loss: 8.693928, Disc gvr Loss: 0.605294
# Step 97: Generator Loss: 9.065914, Disc gvr Loss: 0.330036
# Step 98: Generator Loss: 10.789694, Disc gvr Loss: 0.518883
# Step 99: Generator Loss: 8.038922, Disc gvr Loss: 0.275777
# Step 100: Generator Loss: 10.327401, Disc gvr Loss: 0.475287
# Step 101: Generator Loss: 10.495328, Disc gvr Loss: 0.288722
# Step 102: Generator Loss: 10.165658, Disc gvr Loss: 0.446853
# Step 103: Generator Loss: 9.441529, Disc gvr Loss: 0.461735
# Step 104: Generator Loss: 8.530600, Disc gvr Loss: 0.241089
# Step 105: Generator Loss: 9.855484, Disc gvr Loss: 0.465448
# Step 106: Generator Loss: 8.534026, Disc gvr Loss: 0.317597
# Step 107: Generator Loss: 8.113350, Disc gvr Loss: 0.347394
# Step 108: Generator Loss: 8.485865, Disc gvr Loss: 0.358266
# Step 109: Generator Loss: 8.815049, Disc gvr Loss: 0.583931
# Step 110: Generator Loss: 10.118917, Disc gvr Loss: 0.271170
# Step 111: Generator Loss: 8.607014, Disc gvr Loss: 0.262809
# Step 112: Generator Loss: 9.329492, Disc gvr Loss: 0.644940
# Step 113: Generator Loss: 9.081882, Disc gvr Loss: 0.472448
# Step 114: Generator Loss: 8.425198, Disc gvr Loss: 0.652897
# Step 115: Generator Loss: 8.566284, Disc gvr Loss: 0.468933
# Step 116: Generator Loss: 8.064328, Disc gvr Loss: 0.247483
# Step 117: Generator Loss: 7.775940, Disc gvr Loss: 0.340091
# Step 118: Generator Loss: 10.015151, Disc gvr Loss: 0.511446
# Step 119: Generator Loss: 7.947894, Disc gvr Loss: 0.331106
# Step 120: Generator Loss: 9.209161, Disc gvr Loss: 0.321358
# Step 121: Generator Loss: 8.415681, Disc gvr Loss: 0.524729
# Step 122: Generator Loss: 8.839250, Disc gvr Loss: 0.276418
# Step 123: Generator Loss: 8.397833, Disc gvr Loss: 0.304628
# Step 124: Generator Loss: 10.014081, Disc gvr Loss: 0.466957
# Step 125: Generator Loss: 9.659013, Disc gvr Loss: 0.275108
# Step 126: Generator Loss: 8.870906, Disc gvr Loss: 0.229166
# Step 127: Generator Loss: 9.134483, Disc gvr Loss: 0.271926
# Step 128: Generator Loss: 9.497233, Disc gvr Loss: 0.405924
# Step 129: Generator Loss: 8.768521, Disc gvr Loss: 0.426080
# Step 130: Generator Loss: 9.838309, Disc gvr Loss: 0.532878
# Step 131: Generator Loss: 8.097073, Disc gvr Loss: 0.210189
# Step 132: Generator Loss: 8.312073, Disc gvr Loss: 0.352667
# Step 133: Generator Loss: 7.972127, Disc gvr Loss: 0.408388
# Step 134: Generator Loss: 8.366054, Disc gvr Loss: 0.380680
# Step 135: Generator Loss: 7.950322, Disc gvr Loss: 0.439738
# Step 136: Generator Loss: 8.523170, Disc gvr Loss: 0.347356
# Step 137: Generator Loss: 7.311035, Disc gvr Loss: 0.427430
# Step 138: Generator Loss: 6.852112, Disc gvr Loss: 0.506847
# Step 139: Generator Loss: 6.727617, Disc gvr Loss: 0.665742
# Step 140: Generator Loss: 5.303526, Disc gvr Loss: 0.693165
# Step 141: Generator Loss: 6.525694, Disc gvr Loss: 0.874775
# Step 142: Generator Loss: 8.218989, Disc gvr Loss: 0.399878
# Step 143: Generator Loss: 8.639338, Disc gvr Loss: 0.286864
# Step 144: Generator Loss: 8.870925, Disc gvr Loss: 0.396039
# Step 145: Generator Loss: 11.167300, Disc gvr Loss: 0.332637
# Step 146: Generator Loss: 10.861707, Disc gvr Loss: 0.272954
# Step 147: Generator Loss: 9.606638, Disc gvr Loss: 0.216782
# Step 148: Generator Loss: 10.955561, Disc gvr Loss: 0.427208
# Step 149: Generator Loss: 10.147132, Disc gvr Loss: 0.317002
# Step 150: Generator Loss: 10.284706, Disc gvr Loss: 0.248051
# Step 151: Generator Loss: 10.851641, Disc gvr Loss: 0.292143
# Step 152: Generator Loss: 10.297019, Disc gvr Loss: 0.580598
# Step 153: Generator Loss: 9.061977, Disc gvr Loss: 0.347627
# Step 154: Generator Loss: 9.957538, Disc gvr Loss: 0.354012
# Step 155: Generator Loss: 7.944900, Disc gvr Loss: 0.752456
# Step 156: Generator Loss: 8.726377, Disc gvr Loss: 0.502892
# Step 157: Generator Loss: 7.211943, Disc gvr Loss: 0.229417
# Step 158: Generator Loss: 6.987825, Disc gvr Loss: 0.727116
# Step 159: Generator Loss: 7.692446, Disc gvr Loss: 0.710963
# Step 160: Generator Loss: 7.295053, Disc gvr Loss: 0.534499
# Step 161: Generator Loss: 6.989360, Disc gvr Loss: 0.342573
# Step 162: Generator Loss: 6.387619, Disc gvr Loss: 0.366165
# Step 163: Generator Loss: 8.482693, Disc gvr Loss: 0.614225
# Step 164: Generator Loss: 9.564531, Disc gvr Loss: 0.491543
# Step 165: Generator Loss: 9.729088, Disc gvr Loss: 0.388545
# Step 166: Generator Loss: 9.401638, Disc gvr Loss: 0.204861
# Step 167: Generator Loss: 10.012329, Disc gvr Loss: 0.345542
# Step 168: Generator Loss: 9.624278, Disc gvr Loss: 0.222540
# Step 169: Generator Loss: 10.162738, Disc gvr Loss: 0.351877
# Step 170: Generator Loss: 9.767384, Disc gvr Loss: 0.409415
# Step 171: Generator Loss: 10.056511, Disc gvr Loss: 0.344744
# Step 172: Generator Loss: 8.975763, Disc gvr Loss: 0.350728
# Step 173: Generator Loss: 10.252916, Disc gvr Loss: 0.292604
# Step 174: Generator Loss: 10.174252, Disc gvr Loss: 0.249069
# Step 175: Generator Loss: 9.888985, Disc gvr Loss: 0.283632
# Step 176: Generator Loss: 8.798559, Disc gvr Loss: 0.186089
# Step 177: Generator Loss: 8.883753, Disc gvr Loss: 0.362026
# Step 178: Generator Loss: 8.302047, Disc gvr Loss: 0.498494
# Step 179: Generator Loss: 8.115910, Disc gvr Loss: 0.343344
# Step 180: Generator Loss: 9.594042, Disc gvr Loss: 0.755581
# Step 181: Generator Loss: 10.825033, Disc gvr Loss: 0.455043
# Step 182: Generator Loss: 11.215826, Disc gvr Loss: 0.410211
# Step 183: Generator Loss: 12.554682, Disc gvr Loss: 0.387988
# Step 184: Generator Loss: 13.270059, Disc gvr Loss: 0.207113
# Step 185: Generator Loss: 12.658377, Disc gvr Loss: 0.408275
# Step 186: Generator Loss: 13.617873, Disc gvr Loss: 0.226464
# Step 187: Generator Loss: 13.715499, Disc gvr Loss: 0.204105
# Step 188: Generator Loss: 12.499820, Disc gvr Loss: 0.232587
# Step 189: Generator Loss: 13.143883, Disc gvr Loss: 0.212322
# Step 190: Generator Loss: 12.562543, Disc gvr Loss: 0.313418
# Step 191: Generator Loss: 12.761051, Disc gvr Loss: 0.270326
# Step 192: Generator Loss: 12.627377, Disc gvr Loss: 0.409591
# Step 193: Generator Loss: 12.717717, Disc gvr Loss: 0.212287
# Step 194: Generator Loss: 12.468889, Disc gvr Loss: 0.184472
# Step 195: Generator Loss: 11.665847, Disc gvr Loss: 0.239365
# Step 196: Generator Loss: 12.824632, Disc gvr Loss: 0.221408
# Step 197: Generator Loss: 11.399383, Disc gvr Loss: 0.569167
# Step 198: Generator Loss: 11.863420, Disc gvr Loss: 0.209707
# Step 199: Generator Loss: 11.408115, Disc gvr Loss: 0.446614
# Step 200: Generator Loss: 12.137732, Disc gvr Loss: 0.225479
# Step 201: Generator Loss: 10.576354, Disc gvr Loss: 0.300034
# Step 202: Generator Loss: 11.203875, Disc gvr Loss: 0.252571
# Step 203: Generator Loss: 10.855076, Disc gvr Loss: 0.205305
# Step 204: Generator Loss: 11.778587, Disc gvr Loss: 0.199648
# Step 205: Generator Loss: 10.904108, Disc gvr Loss: 0.530597
# Step 206: Generator Loss: 10.253000, Disc gvr Loss: 0.624242
# Step 207: Generator Loss: 13.034070, Disc gvr Loss: 0.309337
# Step 208: Generator Loss: 13.150126, Disc gvr Loss: 0.277230
# Step 209: Generator Loss: 13.674723, Disc gvr Loss: 0.394130
# Step 210: Generator Loss: 13.180931, Disc gvr Loss: 0.601880
# Step 211: Generator Loss: 11.991668, Disc gvr Loss: 0.245845
# Step 212: Generator Loss: 13.485189, Disc gvr Loss: 0.477568
# Step 213: Generator Loss: 14.563357, Disc gvr Loss: 0.316767
# Step 214: Generator Loss: 15.077320, Disc gvr Loss: 0.224659
# Step 215: Generator Loss: 14.620339, Disc gvr Loss: 0.369406
# Step 216: Generator Loss: 13.898767, Disc gvr Loss: 0.167192
# Step 217: Generator Loss: 13.867605, Disc gvr Loss: 0.226559
# Step 218: Generator Loss: 13.936645, Disc gvr Loss: 0.205182
# Step 219: Generator Loss: 13.352760, Disc gvr Loss: 0.266567
# Step 220: Generator Loss: 14.922678, Disc gvr Loss: 0.235899
# Step 221: Generator Loss: 13.791691, Disc gvr Loss: 0.254921
# Step 222: Generator Loss: 14.455003, Disc gvr Loss: 0.270419
# Step 223: Generator Loss: 15.181214, Disc gvr Loss: 0.242107
# Step 224: Generator Loss: 15.466510, Disc gvr Loss: 0.220388
# Step 225: Generator Loss: 14.890166, Disc gvr Loss: 0.285587
# Step 226: Generator Loss: 14.426083, Disc gvr Loss: 0.340565
# Step 227: Generator Loss: 14.065879, Disc gvr Loss: 0.472746
# Step 228: Generator Loss: 13.897530, Disc gvr Loss: 0.297658
# Step 229: Generator Loss: 15.525198, Disc gvr Loss: 0.271720
# Step 230: Generator Loss: 14.863626, Disc gvr Loss: 0.274596
# Step 231: Generator Loss: 16.425331, Disc gvr Loss: 0.279446
# Step 232: Generator Loss: 15.558351, Disc gvr Loss: 0.203053
# Step 233: Generator Loss: 15.931433, Disc gvr Loss: 0.211537
# Step 234: Generator Loss: 15.272057, Disc gvr Loss: 0.196052
# Step 235: Generator Loss: 15.860173, Disc gvr Loss: 0.208243
# Step 236: Generator Loss: 16.280865, Disc gvr Loss: 0.287125
# Step 237: Generator Loss: 16.770527, Disc gvr Loss: 0.350603
# Step 238: Generator Loss: 17.276957, Disc gvr Loss: 0.188188
# Step 239: Generator Loss: 17.628923, Disc gvr Loss: 0.169046
# Step 240: Generator Loss: 18.096682, Disc gvr Loss: 0.155955
# Step 241: Generator Loss: 18.143349, Disc gvr Loss: 0.302679
# Step 242: Generator Loss: 17.972631, Disc gvr Loss: 0.178769
# Step 243: Generator Loss: 18.420683, Disc gvr Loss: 0.156270
# Step 244: Generator Loss: 18.017719, Disc gvr Loss: 0.176985
# Step 245: Generator Loss: 18.064367, Disc gvr Loss: 0.354148
# Step 246: Generator Loss: 17.586826, Disc gvr Loss: 0.173050
# Step 247: Generator Loss: 18.236017, Disc gvr Loss: 0.159766
# Step 248: Generator Loss: 18.096180, Disc gvr Loss: 0.159168
# Step 249: Generator Loss: 18.034353, Disc gvr Loss: 0.165163
# Step 250: Generator Loss: 17.506411, Disc gvr Loss: 0.510380
# Step 251: Generator Loss: 17.607803, Disc gvr Loss: 0.179692
# Step 252: Generator Loss: 17.937046, Disc gvr Loss: 0.157583
# Step 253: Generator Loss: 18.065788, Disc gvr Loss: 0.172963
# Step 254: Generator Loss: 17.697453, Disc gvr Loss: 0.379873
# Step 255: Generator Loss: 17.486176, Disc gvr Loss: 0.306457
# Step 256: Generator Loss: 18.074282, Disc gvr Loss: 0.251939
# Step 257: Generator Loss: 17.943752, Disc gvr Loss: 0.153681
# Step 258: Generator Loss: 18.106592, Disc gvr Loss: 0.147750
# Step 259: Generator Loss: 18.236492, Disc gvr Loss: 0.301759
# Step 260: Generator Loss: 17.849445, Disc gvr Loss: 0.170024
# Step 261: Generator Loss: 17.891167, Disc gvr Loss: 0.148742
# Step 262: Generator Loss: 17.902740, Disc gvr Loss: 0.179594
# Step 263: Generator Loss: 17.879908, Disc gvr Loss: 0.350375
# Step 264: Generator Loss: 17.916098, Disc gvr Loss: 0.346238
# Step 265: Generator Loss: 18.232460, Disc gvr Loss: 0.160899
# Step 266: Generator Loss: 17.906658, Disc gvr Loss: 0.189952
# Step 267: Generator Loss: 18.200714, Disc gvr Loss: 0.143568
# Step 268: Generator Loss: 17.830862, Disc gvr Loss: 0.185609
# Step 269: Generator Loss: 18.420683, Disc gvr Loss: 0.165883
# Step 270: Generator Loss: 17.975266, Disc gvr Loss: 0.172922
# Step 271: Generator Loss: 17.538288, Disc gvr Loss: 0.200828
# Step 272: Generator Loss: 17.924309, Disc gvr Loss: 0.271752
# Step 273: Generator Loss: 18.001783, Disc gvr Loss: 0.178489
# Step 274: Generator Loss: 18.060085, Disc gvr Loss: 0.142211
# Step 275: Generator Loss: 18.019690, Disc gvr Loss: 0.156650
# Step 276: Generator Loss: 18.057047, Disc gvr Loss: 0.138639
# Step 277: Generator Loss: 17.299829, Disc gvr Loss: 0.189544
# Step 278: Generator Loss: 18.305220, Disc gvr Loss: 0.161515
# Step 279: Generator Loss: 16.877045, Disc gvr Loss: 0.437163
# Step 280: Generator Loss: 18.044819, Disc gvr Loss: 0.170095
# Step 281: Generator Loss: 18.096331, Disc gvr Loss: 0.182632
# Step 282: Generator Loss: 18.064999, Disc gvr Loss: 0.202675
# Step 283: Generator Loss: 17.794895, Disc gvr Loss: 0.339180
# Step 284: Generator Loss: 17.888666, Disc gvr Loss: 0.149881
# Step 285: Generator Loss: 17.216608, Disc gvr Loss: 0.150047
# Step 286: Generator Loss: 17.350105, Disc gvr Loss: 0.199166
# Step 287: Generator Loss: 18.184130, Disc gvr Loss: 0.165256
# Step 288: Generator Loss: 17.683325, Disc gvr Loss: 0.181109
# Step 289: Generator Loss: 17.405233, Disc gvr Loss: 0.223852
# Step 290: Generator Loss: 18.236509, Disc gvr Loss: 0.232603
# Step 291: Generator Loss: 17.647520, Disc gvr Loss: 0.243710
# Step 292: Generator Loss: 17.455891, Disc gvr Loss: 0.243572
# Step 293: Generator Loss: 17.176874, Disc gvr Loss: 0.154983
# Step 294: Generator Loss: 17.673948, Disc gvr Loss: 0.137839
# Step 295: Generator Loss: 18.066580, Disc gvr Loss: 0.175709
# Step 296: Generator Loss: 17.595018, Disc gvr Loss: 0.163053
# Step 297: Generator Loss: 17.696016, Disc gvr Loss: 0.224465
# Step 298: Generator Loss: 17.482759, Disc gvr Loss: 0.187196
# Step 299: Generator Loss: 16.853031, Disc gvr Loss: 0.157712
# Step 300: Generator Loss: 16.500357, Disc gvr Loss: 0.162004
# Step 301: Generator Loss: 17.475653, Disc gvr Loss: 0.160018
# Step 302: Generator Loss: 17.779213, Disc gvr Loss: 0.281026
# Step 303: Generator Loss: 17.818558, Disc gvr Loss: 0.136195
# Step 304: Generator Loss: 17.932232, Disc gvr Loss: 0.169585
# Step 305: Generator Loss: 16.905573, Disc gvr Loss: 0.178127
# Step 306: Generator Loss: 16.667091, Disc gvr Loss: 0.158616
# Step 307: Generator Loss: 16.966421, Disc gvr Loss: 0.377758
# Step 308: Generator Loss: 17.212610, Disc gvr Loss: 0.217009
# Step 309: Generator Loss: 16.645201, Disc gvr Loss: 0.155988
# Step 310: Generator Loss: 16.025230, Disc gvr Loss: 0.172428
# Step 311: Generator Loss: 16.594151, Disc gvr Loss: 0.176023
# Step 312: Generator Loss: 17.684175, Disc gvr Loss: 0.141433
# Step 313: Generator Loss: 16.882984, Disc gvr Loss: 0.183918
# Step 314: Generator Loss: 16.128735, Disc gvr Loss: 0.195615
# Step 315: Generator Loss: 16.645836, Disc gvr Loss: 0.166655
# Step 316: Generator Loss: 16.816656, Disc gvr Loss: 0.177407
# Step 317: Generator Loss: 17.178282, Disc gvr Loss: 0.154909
# Step 318: Generator Loss: 16.678772, Disc gvr Loss: 0.142409
# Step 319: Generator Loss: 16.113354, Disc gvr Loss: 0.208572
# Step 320: Generator Loss: 17.432320, Disc gvr Loss: 0.155715
# Step 321: Generator Loss: 17.101332, Disc gvr Loss: 0.150754
# Step 322: Generator Loss: 16.431852, Disc gvr Loss: 0.180288
# Step 323: Generator Loss: 17.886780, Disc gvr Loss: 0.151718
# Step 324: Generator Loss: 16.373127, Disc gvr Loss: 0.150420
# Step 325: Generator Loss: 16.681486, Disc gvr Loss: 0.186738
# Step 326: Generator Loss: 17.713362, Disc gvr Loss: 0.170368
# Step 327: Generator Loss: 16.453236, Disc gvr Loss: 0.182732
# Step 328: Generator Loss: 15.976755, Disc gvr Loss: 0.170978
# Step 329: Generator Loss: 17.164425, Disc gvr Loss: 0.144726
# Step 330: Generator Loss: 16.507433, Disc gvr Loss: 0.321111
# Step 331: Generator Loss: 16.121449, Disc gvr Loss: 0.203832
# Step 332: Generator Loss: 17.158859, Disc gvr Loss: 0.311946
# Step 333: Generator Loss: 16.481613, Disc gvr Loss: 0.165515
# Step 334: Generator Loss: 16.258041, Disc gvr Loss: 0.172108
# Step 335: Generator Loss: 16.331982, Disc gvr Loss: 0.188985
# Step 336: Generator Loss: 16.223221, Disc gvr Loss: 0.170753
# Step 337: Generator Loss: 16.245749, Disc gvr Loss: 0.197671
# Step 338: Generator Loss: 16.210552, Disc gvr Loss: 0.218516
# Step 339: Generator Loss: 15.935322, Disc gvr Loss: 0.147077
# Step 340: Generator Loss: 16.923302, Disc gvr Loss: 0.166417
# Step 341: Generator Loss: 15.865083, Disc gvr Loss: 0.205077
# Step 342: Generator Loss: 17.177856, Disc gvr Loss: 0.135221
# Step 343: Generator Loss: 17.187147, Disc gvr Loss: 0.131779
# Step 344: Generator Loss: 16.283915, Disc gvr Loss: 0.183996
# Step 345: Generator Loss: 16.120283, Disc gvr Loss: 0.329697
# Step 346: Generator Loss: 16.261145, Disc gvr Loss: 0.250312
# Step 347: Generator Loss: 16.831631, Disc gvr Loss: 0.148006
# Step 348: Generator Loss: 16.004303, Disc gvr Loss: 0.139573
# Step 349: Generator Loss: 16.193439, Disc gvr Loss: 0.227502
# Step 350: Generator Loss: 15.620069, Disc gvr Loss: 0.165339
# Step 351: Generator Loss: 16.715117, Disc gvr Loss: 0.122460
# Step 352: Generator Loss: 15.966247, Disc gvr Loss: 0.151913
# Step 353: Generator Loss: 16.285992, Disc gvr Loss: 0.315362
# Step 354: Generator Loss: 16.127834, Disc gvr Loss: 0.176538
# Step 355: Generator Loss: 16.465412, Disc gvr Loss: 0.182532
# Step 356: Generator Loss: 15.848727, Disc gvr Loss: 0.389873
# Step 357: Generator Loss: 15.910675, Disc gvr Loss: 0.167397
# Step 358: Generator Loss: 15.321580, Disc gvr Loss: 0.209702
# Step 359: Generator Loss: 16.819405, Disc gvr Loss: 0.239219
# Step 360: Generator Loss: 15.384286, Disc gvr Loss: 0.179292
# Step 361: Generator Loss: 15.383849, Disc gvr Loss: 0.155801
# Step 362: Generator Loss: 16.861153, Disc gvr Loss: 0.137454
# Step 363: Generator Loss: 16.009811, Disc gvr Loss: 0.199611
# Step 364: Generator Loss: 14.629256, Disc gvr Loss: 0.294694
# Step 365: Generator Loss: 16.223791, Disc gvr Loss: 0.210346
# Step 366: Generator Loss: 16.346577, Disc gvr Loss: 0.122884
# Step 367: Generator Loss: 16.293781, Disc gvr Loss: 0.179938
# Step 368: Generator Loss: 16.273422, Disc gvr Loss: 0.178399
# Step 369: Generator Loss: 15.335575, Disc gvr Loss: 0.349830
# Step 370: Generator Loss: 16.179272, Disc gvr Loss: 0.157073
# Step 371: Generator Loss: 15.942158, Disc gvr Loss: 0.145732
# Step 372: Generator Loss: 16.457420, Disc gvr Loss: 0.147307
# Step 373: Generator Loss: 16.238270, Disc gvr Loss: 0.161025
# Step 374: Generator Loss: 17.017843, Disc gvr Loss: 0.199644
# Step 375: Generator Loss: 17.302458, Disc gvr Loss: 0.110453
# Step 376: Generator Loss: 15.421039, Disc gvr Loss: 0.257136
# Step 377: Generator Loss: 15.387992, Disc gvr Loss: 0.169385
# Step 378: Generator Loss: 16.397776, Disc gvr Loss: 0.235591
# Step 379: Generator Loss: 15.768663, Disc gvr Loss: 0.169759
# Step 380: Generator Loss: 15.336315, Disc gvr Loss: 0.183692
# Step 381: Generator Loss: 15.231346, Disc gvr Loss: 0.188715
# Step 382: Generator Loss: 16.049423, Disc gvr Loss: 0.209484
# Step 383: Generator Loss: 14.980175, Disc gvr Loss: 0.168752
# Step 384: Generator Loss: 15.076278, Disc gvr Loss: 0.147880
# Step 385: Generator Loss: 16.087597, Disc gvr Loss: 0.208615
# Step 386: Generator Loss: 15.519629, Disc gvr Loss: 0.192574
# Step 387: Generator Loss: 15.955248, Disc gvr Loss: 0.156013
# Step 388: Generator Loss: 14.375196, Disc gvr Loss: 0.182796
# Step 389: Generator Loss: 14.378392, Disc gvr Loss: 0.521029
# Step 390: Generator Loss: 14.730926, Disc gvr Loss: 0.298981
# Step 391: Generator Loss: 14.343044, Disc gvr Loss: 0.441400
# Step 392: Generator Loss: 15.014702, Disc gvr Loss: 0.412837
# Step 393: Generator Loss: 14.197851, Disc gvr Loss: 0.375352
# Step 394: Generator Loss: 15.326594, Disc gvr Loss: 0.181614
# Step 395: Generator Loss: 14.931466, Disc gvr Loss: 0.190536
# Step 396: Generator Loss: 15.711874, Disc gvr Loss: 0.158328
# Step 397: Generator Loss: 15.208576, Disc gvr Loss: 0.161368
# Step 398: Generator Loss: 15.291551, Disc gvr Loss: 0.227303
# Step 399: Generator Loss: 15.320204, Disc gvr Loss: 0.373304
# Step 400: Generator Loss: 15.000824, Disc gvr Loss: 0.234899
# Step 401: Generator Loss: 14.700509, Disc gvr Loss: 0.367430
# Step 402: Generator Loss: 14.967207, Disc gvr Loss: 0.290226
# Step 403: Generator Loss: 15.107187, Disc gvr Loss: 0.239296
# Step 404: Generator Loss: 14.272882, Disc gvr Loss: 0.560399
# Step 405: Generator Loss: 15.280657, Disc gvr Loss: 0.150968
# Step 406: Generator Loss: 14.886742, Disc gvr Loss: 0.212907
# Step 407: Generator Loss: 15.244733, Disc gvr Loss: 0.261011
# Step 408: Generator Loss: 14.252289, Disc gvr Loss: 0.355096
# Step 409: Generator Loss: 15.134605, Disc gvr Loss: 0.178000
# Step 410: Generator Loss: 15.068290, Disc gvr Loss: 0.239608
# Step 411: Generator Loss: 14.843519, Disc gvr Loss: 0.200346
# Step 412: Generator Loss: 16.099922, Disc gvr Loss: 0.259026
# Step 413: Generator Loss: 15.801905, Disc gvr Loss: 0.194412
# Step 414: Generator Loss: 15.904348, Disc gvr Loss: 0.164467
# Step 415: Generator Loss: 15.316658, Disc gvr Loss: 0.152244
# Step 416: Generator Loss: 16.219057, Disc gvr Loss: 0.142309
# Step 417: Generator Loss: 16.371332, Disc gvr Loss: 0.314094
# Step 418: Generator Loss: 16.289705, Disc gvr Loss: 0.126293
# Step 419: Generator Loss: 16.227676, Disc gvr Loss: 0.117752
# Step 420: Generator Loss: 16.054852, Disc gvr Loss: 0.133378
# Step 421: Generator Loss: 16.423918, Disc gvr Loss: 0.153666
# Step 422: Generator Loss: 15.323064, Disc gvr Loss: 0.273426
# Step 423: Generator Loss: 16.010941, Disc gvr Loss: 0.135848
# Step 424: Generator Loss: 14.956629, Disc gvr Loss: 0.160287
# Step 425: Generator Loss: 15.385289, Disc gvr Loss: 0.320558
# Step 426: Generator Loss: 16.155310, Disc gvr Loss: 0.158777
# Step 427: Generator Loss: 15.076093, Disc gvr Loss: 0.142021
# Step 428: Generator Loss: 16.328781, Disc gvr Loss: 0.208782
# Step 429: Generator Loss: 15.707454, Disc gvr Loss: 0.159332
# Step 430: Generator Loss: 15.712519, Disc gvr Loss: 0.202602
# Step 431: Generator Loss: 16.060661, Disc gvr Loss: 0.365166
# Step 432: Generator Loss: 16.811069, Disc gvr Loss: 0.127619
# Step 433: Generator Loss: 16.471563, Disc gvr Loss: 0.141766
# Step 434: Generator Loss: 16.941061, Disc gvr Loss: 0.117370
# Step 435: Generator Loss: 16.729879, Disc gvr Loss: 0.193599
# Step 436: Generator Loss: 15.775461, Disc gvr Loss: 0.152547
# Step 437: Generator Loss: 16.143373, Disc gvr Loss: 0.174099
# Step 438: Generator Loss: 16.459440, Disc gvr Loss: 0.112061
# Step 439: Generator Loss: 14.746978, Disc gvr Loss: 0.231183
# Step 440: Generator Loss: 16.394060, Disc gvr Loss: 0.160713
# Step 441: Generator Loss: 15.226384, Disc gvr Loss: 0.125198
# Step 442: Generator Loss: 15.303754, Disc gvr Loss: 0.205547
# Step 443: Generator Loss: 15.888329, Disc gvr Loss: 0.188826
# Step 444: Generator Loss: 15.755023, Disc gvr Loss: 0.196640
# Step 445: Generator Loss: 14.671865, Disc gvr Loss: 0.261142
# Step 446: Generator Loss: 15.860948, Disc gvr Loss: 0.175930
# Step 447: Generator Loss: 16.292444, Disc gvr Loss: 0.116344
# Step 448: Generator Loss: 15.773955, Disc gvr Loss: 0.195107
# Step 449: Generator Loss: 16.082680, Disc gvr Loss: 0.157141
# Step 450: Generator Loss: 16.463058, Disc gvr Loss: 0.141044
# Step 451: Generator Loss: 16.205471, Disc gvr Loss: 0.309955
# Step 452: Generator Loss: 14.708200, Disc gvr Loss: 0.140398
# Step 453: Generator Loss: 15.432651, Disc gvr Loss: 0.325873
# Step 454: Generator Loss: 16.319744, Disc gvr Loss: 0.272047
# Step 455: Generator Loss: 15.599336, Disc gvr Loss: 0.266378
# Step 456: Generator Loss: 16.309507, Disc gvr Loss: 0.292245
# Step 457: Generator Loss: 15.120915, Disc gvr Loss: 0.548212
# Step 458: Generator Loss: 16.282166, Disc gvr Loss: 0.177845
# Step 459: Generator Loss: 15.812055, Disc gvr Loss: 0.126065
# Step 460: Generator Loss: 16.784540, Disc gvr Loss: 0.131729
# Step 461: Generator Loss: 17.212919, Disc gvr Loss: 0.226923
# Step 462: Generator Loss: 17.263588, Disc gvr Loss: 0.113673
# Step 463: Generator Loss: 15.498024, Disc gvr Loss: 0.595132
# Step 464: Generator Loss: 16.149323, Disc gvr Loss: 0.245754
# Step 465: Generator Loss: 16.072926, Disc gvr Loss: 0.339694
# Step 466: Generator Loss: 16.409864, Disc gvr Loss: 0.327736
# Step 467: Generator Loss: 16.912590, Disc gvr Loss: 0.248126
# Step 468: Generator Loss: 16.710363, Disc gvr Loss: 0.113927
# Step 469: Generator Loss: 16.593353, Disc gvr Loss: 0.220854
# Step 470: Generator Loss: 16.296225, Disc gvr Loss: 0.366764
# Step 471: Generator Loss: 17.077765, Disc gvr Loss: 0.225562
# Step 472: Generator Loss: 16.868256, Disc gvr Loss: 0.167243
# Step 473: Generator Loss: 17.301991, Disc gvr Loss: 0.123904
# Step 474: Generator Loss: 16.738911, Disc gvr Loss: 0.180749
# Step 475: Generator Loss: 17.455698, Disc gvr Loss: 0.139994
# Step 476: Generator Loss: 17.324429, Disc gvr Loss: 0.129109
# Step 477: Generator Loss: 17.378376, Disc gvr Loss: 0.094038
# Step 478: Generator Loss: 17.387156, Disc gvr Loss: 0.254811
# Step 479: Generator Loss: 18.022757, Disc gvr Loss: 0.284634
# Step 480: Generator Loss: 17.077433, Disc gvr Loss: 0.244010
# Step 481: Generator Loss: 18.006401, Disc gvr Loss: 0.113665
# Step 482: Generator Loss: 18.025196, Disc gvr Loss: 0.120955
# Step 483: Generator Loss: 18.027697, Disc gvr Loss: 0.279195
# Step 484: Generator Loss: 17.251774, Disc gvr Loss: 0.142863
# Step 485: Generator Loss: 17.578804, Disc gvr Loss: 0.255383
# Step 486: Generator Loss: 17.508568, Disc gvr Loss: 0.240398
# Step 487: Generator Loss: 17.651848, Disc gvr Loss: 0.268624
# Step 488: Generator Loss: 17.914841, Disc gvr Loss: 0.126317
# Step 489: Generator Loss: 17.855629, Disc gvr Loss: 0.109324
# Step 490: Generator Loss: 17.711113, Disc gvr Loss: 0.113741
# Step 491: Generator Loss: 17.791035, Disc gvr Loss: 0.129563
# Step 492: Generator Loss: 18.081390, Disc gvr Loss: 0.094420
# Step 493: Generator Loss: 17.647850, Disc gvr Loss: 0.136765
# Step 494: Generator Loss: 17.962492, Disc gvr Loss: 0.128167
# Step 495: Generator Loss: 17.359640, Disc gvr Loss: 0.102031
# Step 496: Generator Loss: 17.907171, Disc gvr Loss: 0.119582
# Step 497: Generator Loss: 16.905935, Disc gvr Loss: 0.320862
# Step 498: Generator Loss: 16.848709, Disc gvr Loss: 0.290269
# Step 499: Generator Loss: 16.843027, Disc gvr Loss: 0.188141
# Step 500: Generator Loss: 17.213455, Disc gvr Loss: 0.330917
# Step 501: Generator Loss: 17.408434, Disc gvr Loss: 0.363618
# Step 502: Generator Loss: 17.775187, Disc gvr Loss: 0.148666
# Step 503: Generator Loss: 17.684223, Disc gvr Loss: 0.136924
# Step 504: Generator Loss: 18.366283, Disc gvr Loss: 0.090240
# Step 505: Generator Loss: 17.941584, Disc gvr Loss: 0.103658
# Step 506: Generator Loss: 18.018566, Disc gvr Loss: 0.116853
# Step 507: Generator Loss: 17.601959, Disc gvr Loss: 0.121963
# Step 508: Generator Loss: 17.708168, Disc gvr Loss: 0.130818
# Step 509: Generator Loss: 17.696583, Disc gvr Loss: 0.123969
# Step 510: Generator Loss: 17.490511, Disc gvr Loss: 0.099644
# Step 511: Generator Loss: 18.074564, Disc gvr Loss: 0.135578
# Step 512: Generator Loss: 18.420683, Disc gvr Loss: 0.126162
# Step 513: Generator Loss: 17.168852, Disc gvr Loss: 0.105858
# Step 514: Generator Loss: 17.840412, Disc gvr Loss: 0.109434
# Step 515: Generator Loss: 17.513536, Disc gvr Loss: 0.163428
# Step 516: Generator Loss: 17.899885, Disc gvr Loss: 0.107174
# Step 517: Generator Loss: 17.881323, Disc gvr Loss: 0.104028
# Step 518: Generator Loss: 17.874140, Disc gvr Loss: 0.122125
# Step 519: Generator Loss: 17.359404, Disc gvr Loss: 0.108193
# Step 520: Generator Loss: 17.447573, Disc gvr Loss: 0.176974
# Step 521: Generator Loss: 17.587420, Disc gvr Loss: 0.130482
# Step 522: Generator Loss: 17.526161, Disc gvr Loss: 0.125974
# Step 523: Generator Loss: 17.887945, Disc gvr Loss: 0.100695
# Step 524: Generator Loss: 17.406536, Disc gvr Loss: 0.105175
# Step 525: Generator Loss: 17.924129, Disc gvr Loss: 0.105699
# Step 526: Generator Loss: 17.864973, Disc gvr Loss: 0.115229
# Step 527: Generator Loss: 17.524256, Disc gvr Loss: 0.126209
# Step 528: Generator Loss: 18.065269, Disc gvr Loss: 0.097122
# Step 529: Generator Loss: 17.408154, Disc gvr Loss: 0.138940
# Step 530: Generator Loss: 17.454082, Disc gvr Loss: 0.141208
# Step 531: Generator Loss: 17.221443, Disc gvr Loss: 0.127236
# Step 532: Generator Loss: 17.534508, Disc gvr Loss: 0.105763
# Step 533: Generator Loss: 17.355171, Disc gvr Loss: 0.112873
# Step 534: Generator Loss: 17.468067, Disc gvr Loss: 0.113205
# Step 535: Generator Loss: 17.710335, Disc gvr Loss: 0.108304
# Step 536: Generator Loss: 17.591568, Disc gvr Loss: 0.130517
# Step 537: Generator Loss: 17.186974, Disc gvr Loss: 0.138277
# Step 538: Generator Loss: 17.984909, Disc gvr Loss: 0.123100
# Step 539: Generator Loss: 16.961252, Disc gvr Loss: 0.155557
# Step 540: Generator Loss: 17.001184, Disc gvr Loss: 0.120104
# Step 541: Generator Loss: 16.943312, Disc gvr Loss: 0.110951
# Step 542: Generator Loss: 17.532608, Disc gvr Loss: 0.103879
# Step 543: Generator Loss: 16.814377, Disc gvr Loss: 0.123491
# Step 544: Generator Loss: 16.644770, Disc gvr Loss: 0.158061
# Step 545: Generator Loss: 17.177540, Disc gvr Loss: 0.144852
# Step 546: Generator Loss: 17.792389, Disc gvr Loss: 0.111927
# Step 547: Generator Loss: 17.546345, Disc gvr Loss: 0.136416
# Step 548: Generator Loss: 17.249121, Disc gvr Loss: 0.162485
# Step 549: Generator Loss: 17.532715, Disc gvr Loss: 0.093651
# Step 550: Generator Loss: 17.163710, Disc gvr Loss: 0.123594
# Step 551: Generator Loss: 16.758806, Disc gvr Loss: 0.142053
# Step 552: Generator Loss: 17.341297, Disc gvr Loss: 0.119560
# Step 553: Generator Loss: 17.177513, Disc gvr Loss: 0.133800
# Step 554: Generator Loss: 16.037313, Disc gvr Loss: 0.214767
# Step 555: Generator Loss: 16.999910, Disc gvr Loss: 0.139271
# Step 556: Generator Loss: 17.532698, Disc gvr Loss: 0.155877
# Step 557: Generator Loss: 16.283951, Disc gvr Loss: 0.147594
# Step 558: Generator Loss: 16.752657, Disc gvr Loss: 0.104223
# Step 559: Generator Loss: 16.462265, Disc gvr Loss: 0.122803
# Step 560: Generator Loss: 16.602266, Disc gvr Loss: 0.138135
# Step 561: Generator Loss: 16.656042, Disc gvr Loss: 0.129728
# Step 562: Generator Loss: 15.803117, Disc gvr Loss: 0.160713
# Step 563: Generator Loss: 15.959869, Disc gvr Loss: 0.152355
# Step 564: Generator Loss: 16.594841, Disc gvr Loss: 0.122337
# Step 565: Generator Loss: 16.736183, Disc gvr Loss: 0.159521
# Step 566: Generator Loss: 15.795647, Disc gvr Loss: 0.200948
# Step 567: Generator Loss: 15.920832, Disc gvr Loss: 0.119255
# Step 568: Generator Loss: 16.879137, Disc gvr Loss: 0.131691
# Step 569: Generator Loss: 15.464513, Disc gvr Loss: 0.228695
# Step 570: Generator Loss: 16.048834, Disc gvr Loss: 0.292498
# Step 571: Generator Loss: 16.701090, Disc gvr Loss: 0.170174
# Step 572: Generator Loss: 16.538639, Disc gvr Loss: 0.122313
# Step 573: Generator Loss: 15.431494, Disc gvr Loss: 0.180281
# Step 574: Generator Loss: 15.088849, Disc gvr Loss: 0.206794
# Step 575: Generator Loss: 16.454159, Disc gvr Loss: 0.165028
# Step 576: Generator Loss: 16.359335, Disc gvr Loss: 0.112049
# Step 577: Generator Loss: 15.447483, Disc gvr Loss: 0.169418
# Step 578: Generator Loss: 16.212637, Disc gvr Loss: 0.159195
# Step 579: Generator Loss: 15.712289, Disc gvr Loss: 0.158040
# Step 580: Generator Loss: 15.132483, Disc gvr Loss: 0.199914
# Step 581: Generator Loss: 16.927347, Disc gvr Loss: 0.109197
# Step 582: Generator Loss: 15.934191, Disc gvr Loss: 0.143958
# Step 583: Generator Loss: 15.160439, Disc gvr Loss: 0.186708
# Step 584: Generator Loss: 15.567640, Disc gvr Loss: 0.276172
# Step 585: Generator Loss: 16.884171, Disc gvr Loss: 0.112561
# Step 586: Generator Loss: 16.341490, Disc gvr Loss: 0.113449
# Step 587: Generator Loss: 15.768484, Disc gvr Loss: 0.127733
# Step 588: Generator Loss: 15.070166, Disc gvr Loss: 0.170024
# Step 589: Generator Loss: 15.846379, Disc gvr Loss: 0.122663
# Step 590: Generator Loss: 15.564531, Disc gvr Loss: 0.173250
# Step 591: Generator Loss: 15.417444, Disc gvr Loss: 0.139982
# Step 592: Generator Loss: 13.705239, Disc gvr Loss: 0.565714
# Step 593: Generator Loss: 15.372074, Disc gvr Loss: 0.163633
# Step 594: Generator Loss: 14.603944, Disc gvr Loss: 0.169447
# Step 595: Generator Loss: 14.752424, Disc gvr Loss: 0.185961
# Step 596: Generator Loss: 15.650272, Disc gvr Loss: 0.151053
# Step 597: Generator Loss: 15.272933, Disc gvr Loss: 0.181236
# Step 598: Generator Loss: 15.256842, Disc gvr Loss: 0.171641
# Step 599: Generator Loss: 15.589273, Disc gvr Loss: 0.168827
# Step 600: Generator Loss: 15.412755, Disc gvr Loss: 0.137722
# Step 601: Generator Loss: 15.943098, Disc gvr Loss: 0.160671
# Step 602: Generator Loss: 15.217242, Disc gvr Loss: 0.176949
# Step 603: Generator Loss: 15.361499, Disc gvr Loss: 0.143832
# Step 604: Generator Loss: 14.427650, Disc gvr Loss: 0.155402
# Step 605: Generator Loss: 15.802615, Disc gvr Loss: 0.127819
# Step 606: Generator Loss: 15.014338, Disc gvr Loss: 0.333168
# Step 607: Generator Loss: 15.725217, Disc gvr Loss: 0.153525
# Step 608: Generator Loss: 15.807270, Disc gvr Loss: 0.163992
# Step 609: Generator Loss: 15.773652, Disc gvr Loss: 0.131320
# Step 610: Generator Loss: 15.696109, Disc gvr Loss: 0.164016
# Step 611: Generator Loss: 15.582667, Disc gvr Loss: 0.322099
# Step 612: Generator Loss: 15.402536, Disc gvr Loss: 0.116162
# Step 613: Generator Loss: 16.053370, Disc gvr Loss: 0.102579
# Step 614: Generator Loss: 17.109875, Disc gvr Loss: 0.099460
# Step 615: Generator Loss: 15.832106, Disc gvr Loss: 0.152582
# Step 616: Generator Loss: 16.661703, Disc gvr Loss: 0.299198
# Step 617: Generator Loss: 14.795348, Disc gvr Loss: 0.386334
# Step 618: Generator Loss: 16.740227, Disc gvr Loss: 0.128266
# Step 619: Generator Loss: 15.180789, Disc gvr Loss: 0.379078
# Step 620: Generator Loss: 15.940941, Disc gvr Loss: 0.120262
# Step 621: Generator Loss: 16.226439, Disc gvr Loss: 0.280746
# Step 622: Generator Loss: 16.959244, Disc gvr Loss: 0.311152
# Step 623: Generator Loss: 17.050962, Disc gvr Loss: 0.171678
# Step 624: Generator Loss: 17.292879, Disc gvr Loss: 0.317173
# Step 625: Generator Loss: 17.245998, Disc gvr Loss: 0.109403
# Step 626: Generator Loss: 17.557129, Disc gvr Loss: 0.239841
# Step 627: Generator Loss: 16.104036, Disc gvr Loss: 0.279971
# Step 628: Generator Loss: 16.752295, Disc gvr Loss: 0.115031
# Step 629: Generator Loss: 16.688967, Disc gvr Loss: 0.130532
# Step 630: Generator Loss: 15.794040, Disc gvr Loss: 0.224267
# Step 631: Generator Loss: 15.672260, Disc gvr Loss: 0.175170
# Step 632: Generator Loss: 15.834223, Disc gvr Loss: 0.154990
# Step 633: Generator Loss: 16.733131, Disc gvr Loss: 0.137423
# Step 634: Generator Loss: 16.703283, Disc gvr Loss: 0.184047
# Step 635: Generator Loss: 17.337479, Disc gvr Loss: 0.093079
# Step 636: Generator Loss: 17.311975, Disc gvr Loss: 0.090849
# Step 637: Generator Loss: 16.775869, Disc gvr Loss: 0.302563
# Step 638: Generator Loss: 16.834362, Disc gvr Loss: 0.161881
# Step 639: Generator Loss: 17.980448, Disc gvr Loss: 0.086171
# Step 640: Generator Loss: 16.965017, Disc gvr Loss: 0.095325
# Step 641: Generator Loss: 17.548904, Disc gvr Loss: 0.102016
# Step 642: Generator Loss: 17.601131, Disc gvr Loss: 0.129973
# Step 643: Generator Loss: 17.891884, Disc gvr Loss: 0.093489
# Step 644: Generator Loss: 17.540331, Disc gvr Loss: 0.099170
# Step 645: Generator Loss: 17.809202, Disc gvr Loss: 0.082856
# Step 646: Generator Loss: 17.346956, Disc gvr Loss: 0.118088
# Step 647: Generator Loss: 17.881222, Disc gvr Loss: 0.151861
# Step 648: Generator Loss: 18.021635, Disc gvr Loss: 0.085317
# Step 649: Generator Loss: 17.460691, Disc gvr Loss: 0.157292
# Step 650: Generator Loss: 17.552876, Disc gvr Loss: 0.106493
# Step 651: Generator Loss: 18.124880, Disc gvr Loss: 0.094913
# Step 652: Generator Loss: 17.626032, Disc gvr Loss: 0.091190
# Step 653: Generator Loss: 17.656614, Disc gvr Loss: 0.099490
# Step 654: Generator Loss: 17.566925, Disc gvr Loss: 0.103486
# Step 655: Generator Loss: 17.361526, Disc gvr Loss: 0.104669
# Step 656: Generator Loss: 17.890514, Disc gvr Loss: 0.286858
# Step 657: Generator Loss: 17.155035, Disc gvr Loss: 0.345694
# Step 658: Generator Loss: 17.559141, Disc gvr Loss: 0.179771
# Step 659: Generator Loss: 17.414196, Disc gvr Loss: 0.155374
# Step 660: Generator Loss: 17.879608, Disc gvr Loss: 0.096104
# Step 661: Generator Loss: 17.947378, Disc gvr Loss: 0.083875
# Step 662: Generator Loss: 17.858440, Disc gvr Loss: 0.098517
# Step 663: Generator Loss: 17.471813, Disc gvr Loss: 0.084758
# Step 664: Generator Loss: 17.669933, Disc gvr Loss: 0.108817
# Step 665: Generator Loss: 17.727354, Disc gvr Loss: 0.112038
# Step 666: Generator Loss: 17.424311, Disc gvr Loss: 0.189251
# Step 667: Generator Loss: 17.003561, Disc gvr Loss: 0.335544
# Step 668: Generator Loss: 17.721447, Disc gvr Loss: 0.104664
# Step 669: Generator Loss: 17.841139, Disc gvr Loss: 0.096319
# Step 670: Generator Loss: 17.543350, Disc gvr Loss: 0.081126
# Step 671: Generator Loss: 17.820137, Disc gvr Loss: 0.106466
# Step 672: Generator Loss: 17.430998, Disc gvr Loss: 0.090303
# Step 673: Generator Loss: 17.257633, Disc gvr Loss: 0.153670
# Step 674: Generator Loss: 17.849829, Disc gvr Loss: 0.106160
# Step 675: Generator Loss: 17.572098, Disc gvr Loss: 0.081045
# Step 676: Generator Loss: 17.791559, Disc gvr Loss: 0.081752
# Step 677: Generator Loss: 17.845066, Disc gvr Loss: 0.086873
# Step 678: Generator Loss: 17.648840, Disc gvr Loss: 0.089741
# Step 679: Generator Loss: 17.077282, Disc gvr Loss: 0.096548
# Step 680: Generator Loss: 17.427710, Disc gvr Loss: 0.138429
# Step 681: Generator Loss: 16.786072, Disc gvr Loss: 0.081311
# Step 682: Generator Loss: 17.588215, Disc gvr Loss: 0.128585
# Step 683: Generator Loss: 17.274792, Disc gvr Loss: 0.138732
# Step 684: Generator Loss: 17.515079, Disc gvr Loss: 0.155735
# Step 685: Generator Loss: 18.068657, Disc gvr Loss: 0.167029
# Step 686: Generator Loss: 17.710602, Disc gvr Loss: 0.092756
# Step 687: Generator Loss: 17.635641, Disc gvr Loss: 0.096808
# Step 688: Generator Loss: 17.702852, Disc gvr Loss: 0.105838
# Step 689: Generator Loss: 17.520241, Disc gvr Loss: 0.089149
# Step 690: Generator Loss: 17.793139, Disc gvr Loss: 0.181963
# Step 691: Generator Loss: 18.131992, Disc gvr Loss: 0.096220
# Step 692: Generator Loss: 18.081295, Disc gvr Loss: 0.098862
# Step 693: Generator Loss: 17.726118, Disc gvr Loss: 0.079158
# Step 694: Generator Loss: 16.899813, Disc gvr Loss: 0.096401
# Step 695: Generator Loss: 17.709419, Disc gvr Loss: 0.087655
# Step 696: Generator Loss: 17.244726, Disc gvr Loss: 0.098518
# Step 697: Generator Loss: 17.612707, Disc gvr Loss: 0.078477
# Step 698: Generator Loss: 17.436373, Disc gvr Loss: 0.085443
# Step 699: Generator Loss: 17.529135, Disc gvr Loss: 0.096905
# Step 700: Generator Loss: 17.328506, Disc gvr Loss: 0.290519
# Step 701: Generator Loss: 17.775263, Disc gvr Loss: 0.095608
# Step 702: Generator Loss: 16.892012, Disc gvr Loss: 0.603178
# Step 703: Generator Loss: 17.233036, Disc gvr Loss: 0.345694
# Step 704: Generator Loss: 16.829247, Disc gvr Loss: 0.149787
# Step 705: Generator Loss: 17.617493, Disc gvr Loss: 0.161982
# Step 706: Generator Loss: 17.555565, Disc gvr Loss: 0.088010
# Step 707: Generator Loss: 17.658476, Disc gvr Loss: 0.094956
# Step 708: Generator Loss: 18.146023, Disc gvr Loss: 0.081565
# Step 709: Generator Loss: 17.824022, Disc gvr Loss: 0.094903
# Step 710: Generator Loss: 17.741461, Disc gvr Loss: 0.090779
# Step 711: Generator Loss: 17.900257, Disc gvr Loss: 0.084660
# Step 712: Generator Loss: 17.794592, Disc gvr Loss: 0.075621
# Step 713: Generator Loss: 17.626865, Disc gvr Loss: 0.099254
# Step 714: Generator Loss: 17.404760, Disc gvr Loss: 0.093238
# Step 715: Generator Loss: 17.216038, Disc gvr Loss: 0.199983
# Step 716: Generator Loss: 17.909639, Disc gvr Loss: 0.082386
# Step 717: Generator Loss: 17.504114, Disc gvr Loss: 0.139538
# Step 718: Generator Loss: 16.723616, Disc gvr Loss: 0.132182
# Step 719: Generator Loss: 17.623590, Disc gvr Loss: 0.088831
# Step 720: Generator Loss: 16.758446, Disc gvr Loss: 0.623515
# Step 721: Generator Loss: 18.136122, Disc gvr Loss: 0.074076
# Step 722: Generator Loss: 17.119987, Disc gvr Loss: 0.089684
# Step 723: Generator Loss: 17.210686, Disc gvr Loss: 0.164630
# Step 724: Generator Loss: 17.868841, Disc gvr Loss: 0.075943
# Step 725: Generator Loss: 17.417814, Disc gvr Loss: 0.092313
# Step 726: Generator Loss: 17.476196, Disc gvr Loss: 0.081772
# Step 727: Generator Loss: 17.756567, Disc gvr Loss: 0.098057
# Step 728: Generator Loss: 17.661392, Disc gvr Loss: 0.095945
# Step 729: Generator Loss: 17.527990, Disc gvr Loss: 0.087424
# Step 730: Generator Loss: 17.586166, Disc gvr Loss: 0.083995
# Step 731: Generator Loss: 17.441523, Disc gvr Loss: 0.170625
# Step 732: Generator Loss: 17.262682, Disc gvr Loss: 0.286286
# Step 733: Generator Loss: 17.445843, Disc gvr Loss: 0.082546
# Step 734: Generator Loss: 16.706955, Disc gvr Loss: 0.197280
# Step 735: Generator Loss: 18.058805, Disc gvr Loss: 0.073727
# Step 736: Generator Loss: 17.328161, Disc gvr Loss: 0.338939
# Step 737: Generator Loss: 17.943846, Disc gvr Loss: 0.087413
# Step 738: Generator Loss: 17.120455, Disc gvr Loss: 0.092503
# Step 739: Generator Loss: 16.851191, Disc gvr Loss: 0.105529
# Step 740: Generator Loss: 17.681376, Disc gvr Loss: 0.081053
# Step 741: Generator Loss: 17.796541, Disc gvr Loss: 0.157031
# Step 742: Generator Loss: 17.353933, Disc gvr Loss: 0.205853
# Step 743: Generator Loss: 16.823082, Disc gvr Loss: 0.108131
# Step 744: Generator Loss: 17.152859, Disc gvr Loss: 0.094606
# Step 745: Generator Loss: 17.887659, Disc gvr Loss: 0.115521
# Step 746: Generator Loss: 17.562178, Disc gvr Loss: 0.084889
# Step 747: Generator Loss: 17.174664, Disc gvr Loss: 0.110937
# Step 748: Generator Loss: 17.533270, Disc gvr Loss: 0.098614
# Step 749: Generator Loss: 17.449499, Disc gvr Loss: 0.087710
# Step 750: Generator Loss: 17.354620, Disc gvr Loss: 0.123569
# Step 751: Generator Loss: 17.543383, Disc gvr Loss: 0.089219
# Step 752: Generator Loss: 17.215521, Disc gvr Loss: 0.097549
# Step 753: Generator Loss: 17.404850, Disc gvr Loss: 0.071655
# Step 754: Generator Loss: 16.997538, Disc gvr Loss: 0.131873
# Step 755: Generator Loss: 17.385845, Disc gvr Loss: 0.092285
# Step 756: Generator Loss: 18.078480, Disc gvr Loss: 0.078837
# Step 757: Generator Loss: 17.444471, Disc gvr Loss: 0.093137
# Step 758: Generator Loss: 17.440706, Disc gvr Loss: 0.089188
# Step 759: Generator Loss: 17.713264, Disc gvr Loss: 0.088308
# Step 760: Generator Loss: 17.105650, Disc gvr Loss: 0.109043
# Step 761: Generator Loss: 17.438046, Disc gvr Loss: 0.083209
# Step 762: Generator Loss: 17.350140, Disc gvr Loss: 0.073279
# Step 763: Generator Loss: 17.345127, Disc gvr Loss: 0.129101
# Step 764: Generator Loss: 17.602562, Disc gvr Loss: 0.091385
# Step 765: Generator Loss: 17.167233, Disc gvr Loss: 0.090647
# Step 766: Generator Loss: 18.025581, Disc gvr Loss: 0.080669
# Step 767: Generator Loss: 17.724110, Disc gvr Loss: 0.083603
# Step 768: Generator Loss: 18.052031, Disc gvr Loss: 0.268172
# Step 769: Generator Loss: 17.889511, Disc gvr Loss: 0.074220
# Step 770: Generator Loss: 18.159676, Disc gvr Loss: 0.075722
# Step 771: Generator Loss: 18.204378, Disc gvr Loss: 0.063347
# Step 772: Generator Loss: 18.045328, Disc gvr Loss: 0.105322
# Step 773: Generator Loss: 18.401281, Disc gvr Loss: 0.082796
# Step 774: Generator Loss: 18.008604, Disc gvr Loss: 0.082909
# Step 775: Generator Loss: 18.061878, Disc gvr Loss: 0.071516
# Step 776: Generator Loss: 17.963760, Disc gvr Loss: 0.090021
# Step 777: Generator Loss: 18.290539, Disc gvr Loss: 0.083800
# Step 778: Generator Loss: 18.117182, Disc gvr Loss: 0.073002
# Step 779: Generator Loss: 18.104673, Disc gvr Loss: 0.074427
# Step 780: Generator Loss: 18.065300, Disc gvr Loss: 0.067993
# Step 781: Generator Loss: 17.630997, Disc gvr Loss: 0.111393
# Step 782: Generator Loss: 18.128021, Disc gvr Loss: 0.082035
# Step 783: Generator Loss: 17.876305, Disc gvr Loss: 0.075809
# Step 784: Generator Loss: 17.634886, Disc gvr Loss: 0.068822
# Step 785: Generator Loss: 17.636948, Disc gvr Loss: 0.089875
# Step 786: Generator Loss: 17.756712, Disc gvr Loss: 0.090276
# Step 787: Generator Loss: 18.110283, Disc gvr Loss: 0.071569
# Step 788: Generator Loss: 17.747122, Disc gvr Loss: 0.080973
# Step 789: Generator Loss: 17.823275, Disc gvr Loss: 0.249208
# Step 790: Generator Loss: 18.025951, Disc gvr Loss: 0.092868
# Step 791: Generator Loss: 17.538969, Disc gvr Loss: 0.080287
# Step 792: Generator Loss: 17.910803, Disc gvr Loss: 0.077150
# Step 793: Generator Loss: 17.789484, Disc gvr Loss: 0.080677
# Step 794: Generator Loss: 17.694277, Disc gvr Loss: 0.084138
# Step 795: Generator Loss: 17.601568, Disc gvr Loss: 0.100528
# Step 796: Generator Loss: 17.650492, Disc gvr Loss: 0.095105
# Step 797: Generator Loss: 17.546309, Disc gvr Loss: 0.080787
# Step 798: Generator Loss: 17.262810, Disc gvr Loss: 0.167025
# Step 799: Generator Loss: 17.421684, Disc gvr Loss: 0.126864
# Step 800: Generator Loss: 17.765409, Disc gvr Loss: 0.077418
# Step 801: Generator Loss: 18.031853, Disc gvr Loss: 0.084801
# Step 802: Generator Loss: 17.882843, Disc gvr Loss: 0.083953
# Step 803: Generator Loss: 17.199169, Disc gvr Loss: 0.096140
# Step 804: Generator Loss: 17.367401, Disc gvr Loss: 0.092190
# Step 805: Generator Loss: 17.703363, Disc gvr Loss: 0.264510
# Step 806: Generator Loss: 18.377054, Disc gvr Loss: 0.068975
# Step 807: Generator Loss: 18.117006, Disc gvr Loss: 0.063481
# Step 808: Generator Loss: 17.839430, Disc gvr Loss: 0.099450
# Step 809: Generator Loss: 17.282581, Disc gvr Loss: 0.092854
# Step 810: Generator Loss: 18.030127, Disc gvr Loss: 0.082640
# Step 811: Generator Loss: 17.794386, Disc gvr Loss: 0.080472
# Step 812: Generator Loss: 17.774193, Disc gvr Loss: 0.081192
# Step 813: Generator Loss: 17.919971, Disc gvr Loss: 0.087025
# Step 814: Generator Loss: 17.945715, Disc gvr Loss: 0.129140
# Step 815: Generator Loss: 18.065266, Disc gvr Loss: 0.076497
# Step 816: Generator Loss: 18.002996, Disc gvr Loss: 0.064661
# Step 817: Generator Loss: 18.036230, Disc gvr Loss: 0.101533
# Step 818: Generator Loss: 17.323378, Disc gvr Loss: 0.209566
# Step 819: Generator Loss: 17.692430, Disc gvr Loss: 0.075831
# Step 820: Generator Loss: 17.075260, Disc gvr Loss: 0.203409
# Step 821: Generator Loss: 17.865528, Disc gvr Loss: 0.071873
# Step 822: Generator Loss: 17.966162, Disc gvr Loss: 0.078035
# Step 823: Generator Loss: 17.387035, Disc gvr Loss: 0.093620
# Step 824: Generator Loss: 17.769455, Disc gvr Loss: 0.075979
# Step 825: Generator Loss: 17.417770, Disc gvr Loss: 0.112725
# Step 826: Generator Loss: 17.912872, Disc gvr Loss: 0.137461
# Step 827: Generator Loss: 17.611145, Disc gvr Loss: 0.076514
# Step 828: Generator Loss: 17.558014, Disc gvr Loss: 0.084823
# Step 829: Generator Loss: 17.769184, Disc gvr Loss: 0.077945
# Step 830: Generator Loss: 17.901369, Disc gvr Loss: 0.067552
# Step 831: Generator Loss: 17.569193, Disc gvr Loss: 0.091878
# Step 832: Generator Loss: 17.878178, Disc gvr Loss: 0.072637
# Step 833: Generator Loss: 17.955719, Disc gvr Loss: 0.068554
# Step 834: Generator Loss: 17.233606, Disc gvr Loss: 0.249642
# Step 835: Generator Loss: 17.169333, Disc gvr Loss: 0.099665
# Step 836: Generator Loss: 17.839066, Disc gvr Loss: 0.090919
# Step 837: Generator Loss: 17.751846, Disc gvr Loss: 0.082578
# Step 838: Generator Loss: 17.858145, Disc gvr Loss: 0.083790
# Step 839: Generator Loss: 17.091743, Disc gvr Loss: 0.072426
# Step 840: Generator Loss: 17.623547, Disc gvr Loss: 0.098271
# Step 841: Generator Loss: 17.328321, Disc gvr Loss: 0.176998
# Step 842: Generator Loss: 17.307636, Disc gvr Loss: 0.093842
# Step 843: Generator Loss: 17.493786, Disc gvr Loss: 0.068187
# Step 844: Generator Loss: 17.541170, Disc gvr Loss: 0.090538
# Step 845: Generator Loss: 16.789064, Disc gvr Loss: 0.098511
# Step 846: Generator Loss: 17.487823, Disc gvr Loss: 0.081533
# Step 847: Generator Loss: 18.072268, Disc gvr Loss: 0.067907
# Step 848: Generator Loss: 17.645792, Disc gvr Loss: 0.080659
# Step 849: Generator Loss: 16.592985, Disc gvr Loss: 0.248892
# Step 850: Generator Loss: 17.432594, Disc gvr Loss: 0.081492
# Step 851: Generator Loss: 16.115755, Disc gvr Loss: 0.102692
# Step 852: Generator Loss: 17.517159, Disc gvr Loss: 0.066671
# Step 853: Generator Loss: 17.396778, Disc gvr Loss: 0.279056
# Step 854: Generator Loss: 16.759672, Disc gvr Loss: 0.103254
# Step 855: Generator Loss: 17.962502, Disc gvr Loss: 0.074743
# Step 856: Generator Loss: 17.390539, Disc gvr Loss: 0.079363
# Step 857: Generator Loss: 17.600479, Disc gvr Loss: 0.062608
# Step 858: Generator Loss: 16.756084, Disc gvr Loss: 0.110901
# Step 859: Generator Loss: 17.230169, Disc gvr Loss: 0.071138
# Step 860: Generator Loss: 16.774242, Disc gvr Loss: 0.108399
# Step 861: Generator Loss: 17.043243, Disc gvr Loss: 0.082452
# Step 862: Generator Loss: 17.088087, Disc gvr Loss: 0.107935
# Step 863: Generator Loss: 16.724798, Disc gvr Loss: 0.092115
# Step 864: Generator Loss: 16.246124, Disc gvr Loss: 0.112911
# Step 865: Generator Loss: 17.070093, Disc gvr Loss: 0.093819
# Step 866: Generator Loss: 17.216217, Disc gvr Loss: 0.091060
# Step 867: Generator Loss: 17.348507, Disc gvr Loss: 0.095540
# Step 868: Generator Loss: 17.344568, Disc gvr Loss: 0.066558
# Step 869: Generator Loss: 17.056660, Disc gvr Loss: 0.079626
# Step 870: Generator Loss: 16.768555, Disc gvr Loss: 0.067554
# Step 871: Generator Loss: 17.096045, Disc gvr Loss: 0.087372
# Step 872: Generator Loss: 17.438190, Disc gvr Loss: 0.103918
# Step 873: Generator Loss: 16.948889, Disc gvr Loss: 0.091585
# Step 874: Generator Loss: 17.531746, Disc gvr Loss: 0.054812
# Step 875: Generator Loss: 15.393386, Disc gvr Loss: 0.115160
# Step 876: Generator Loss: 15.982929, Disc gvr Loss: 0.127884
# Step 877: Generator Loss: 16.430180, Disc gvr Loss: 0.086772
# Step 878: Generator Loss: 16.558754, Disc gvr Loss: 0.083987
# Step 879: Generator Loss: 17.247902, Disc gvr Loss: 0.120632
# Step 880: Generator Loss: 16.494621, Disc gvr Loss: 0.083771
# Step 881: Generator Loss: 16.091429, Disc gvr Loss: 0.114337
# Step 882: Generator Loss: 16.254461, Disc gvr Loss: 0.082538
# Step 883: Generator Loss: 16.432196, Disc gvr Loss: 0.083048
# Step 884: Generator Loss: 16.490952, Disc gvr Loss: 0.223441
# Step 885: Generator Loss: 16.352751, Disc gvr Loss: 0.128730
# Step 886: Generator Loss: 15.818191, Disc gvr Loss: 0.137539
# Step 887: Generator Loss: 16.927330, Disc gvr Loss: 0.098375
# Step 888: Generator Loss: 16.666468, Disc gvr Loss: 0.070096
# Step 889: Generator Loss: 17.523981, Disc gvr Loss: 0.090006
# Step 890: Generator Loss: 16.357784, Disc gvr Loss: 0.112860
# Step 891: Generator Loss: 17.278015, Disc gvr Loss: 0.106405
# Step 892: Generator Loss: 16.061369, Disc gvr Loss: 0.107557
# Step 893: Generator Loss: 16.140707, Disc gvr Loss: 0.074261
# Step 894: Generator Loss: 17.180700, Disc gvr Loss: 0.111530
# Step 895: Generator Loss: 17.111702, Disc gvr Loss: 0.066832
# Step 896: Generator Loss: 17.269693, Disc gvr Loss: 0.093924
# Step 897: Generator Loss: 16.575781, Disc gvr Loss: 0.088018
# Step 898: Generator Loss: 17.002058, Disc gvr Loss: 0.086828
# Step 899: Generator Loss: 16.791979, Disc gvr Loss: 0.101314
# Step 900: Generator Loss: 17.205446, Disc gvr Loss: 0.084803
# Step 901: Generator Loss: 17.160831, Disc gvr Loss: 0.107058
# Step 902: Generator Loss: 17.868092, Disc gvr Loss: 0.142979
# Step 903: Generator Loss: 17.247637, Disc gvr Loss: 0.109088
# Step 904: Generator Loss: 16.951366, Disc gvr Loss: 0.251529
# Step 905: Generator Loss: 17.154411, Disc gvr Loss: 0.091126
# Step 906: Generator Loss: 17.221260, Disc gvr Loss: 0.065221
# Step 907: Generator Loss: 16.843613, Disc gvr Loss: 0.111120
# Step 908: Generator Loss: 17.478628, Disc gvr Loss: 0.104362
# Step 909: Generator Loss: 16.883940, Disc gvr Loss: 0.216062
# Step 910: Generator Loss: 15.993767, Disc gvr Loss: 0.211714
# Step 911: Generator Loss: 17.515369, Disc gvr Loss: 0.084474
# Step 912: Generator Loss: 16.635561, Disc gvr Loss: 0.275332
# Step 913: Generator Loss: 16.494963, Disc gvr Loss: 0.083764
# Step 914: Generator Loss: 16.305031, Disc gvr Loss: 0.139036
# Step 915: Generator Loss: 16.666342, Disc gvr Loss: 0.094467
# Step 916: Generator Loss: 16.524881, Disc gvr Loss: 0.423922
# Step 917: Generator Loss: 17.394781, Disc gvr Loss: 0.121292
# Step 918: Generator Loss: 16.470215, Disc gvr Loss: 0.117690
# Step 919: Generator Loss: 16.007666, Disc gvr Loss: 0.079361
# Step 920: Generator Loss: 16.651806, Disc gvr Loss: 0.113710
# Step 921: Generator Loss: 16.537966, Disc gvr Loss: 0.270682
# Step 922: Generator Loss: 16.965530, Disc gvr Loss: 0.088104
# Step 923: Generator Loss: 16.811890, Disc gvr Loss: 0.113533
# Step 924: Generator Loss: 16.135927, Disc gvr Loss: 0.095849
# Step 925: Generator Loss: 17.699200, Disc gvr Loss: 0.086580
# Step 926: Generator Loss: 16.495119, Disc gvr Loss: 0.125568
# Step 927: Generator Loss: 16.814095, Disc gvr Loss: 0.106430
# Step 928: Generator Loss: 16.531818, Disc gvr Loss: 0.077415
# Step 929: Generator Loss: 16.487619, Disc gvr Loss: 0.220318
# Step 930: Generator Loss: 17.005243, Disc gvr Loss: 0.070320
# Step 931: Generator Loss: 16.902092, Disc gvr Loss: 0.100614
# Step 932: Generator Loss: 16.873196, Disc gvr Loss: 0.106623
# Step 933: Generator Loss: 17.351597, Disc gvr Loss: 0.056159
# Step 934: Generator Loss: 16.278204, Disc gvr Loss: 0.131116
# Step 935: Generator Loss: 16.351292, Disc gvr Loss: 0.261890
# Step 936: Generator Loss: 17.802376, Disc gvr Loss: 0.081100
# Step 937: Generator Loss: 16.236065, Disc gvr Loss: 0.078558
# Step 938: Generator Loss: 16.240677, Disc gvr Loss: 0.206310
# Step 939: Generator Loss: 16.461212, Disc gvr Loss: 0.348661
# Step 940: Generator Loss: 16.443872, Disc gvr Loss: 0.085877
# Step 941: Generator Loss: 16.873652, Disc gvr Loss: 0.112599
# Step 942: Generator Loss: 16.658276, Disc gvr Loss: 0.077133
# Step 943: Generator Loss: 16.490902, Disc gvr Loss: 0.153923
# Step 944: Generator Loss: 16.114872, Disc gvr Loss: 0.110778
# Step 945: Generator Loss: 16.915096, Disc gvr Loss: 0.094369
# Step 946: Generator Loss: 15.818110, Disc gvr Loss: 0.131359
# Step 947: Generator Loss: 17.360689, Disc gvr Loss: 0.085687
# Step 948: Generator Loss: 17.764900, Disc gvr Loss: 0.071157
# Step 949: Generator Loss: 17.290970, Disc gvr Loss: 0.087178
# Step 950: Generator Loss: 17.072607, Disc gvr Loss: 0.076328
# Step 951: Generator Loss: 16.940695, Disc gvr Loss: 0.072058
# Step 952: Generator Loss: 17.324459, Disc gvr Loss: 0.085431
# Step 953: Generator Loss: 16.965256, Disc gvr Loss: 0.093575
# Step 954: Generator Loss: 17.259130, Disc gvr Loss: 0.081632
# Step 955: Generator Loss: 17.384485, Disc gvr Loss: 0.072021
# Step 956: Generator Loss: 16.621332, Disc gvr Loss: 0.092160
# Step 957: Generator Loss: 17.091015, Disc gvr Loss: 0.087100
# Step 958: Generator Loss: 17.105984, Disc gvr Loss: 0.120028
# Step 959: Generator Loss: 17.842300, Disc gvr Loss: 0.069798
# Step 960: Generator Loss: 16.827253, Disc gvr Loss: 0.069733
# Step 961: Generator Loss: 17.066290, Disc gvr Loss: 0.147475
# Step 962: Generator Loss: 16.833626, Disc gvr Loss: 0.367784
# Step 963: Generator Loss: 17.494652, Disc gvr Loss: 0.216713
# Step 964: Generator Loss: 17.203941, Disc gvr Loss: 0.081327
# Step 965: Generator Loss: 16.448809, Disc gvr Loss: 0.092361
# Step 966: Generator Loss: 17.601555, Disc gvr Loss: 0.249051
# Step 967: Generator Loss: 16.955313, Disc gvr Loss: 0.336991
# Step 968: Generator Loss: 17.062992, Disc gvr Loss: 0.071094
# Step 969: Generator Loss: 16.534159, Disc gvr Loss: 0.490401
# Step 970: Generator Loss: 17.705465, Disc gvr Loss: 0.257507
# Step 971: Generator Loss: 17.404371, Disc gvr Loss: 0.365157
# Step 972: Generator Loss: 17.014307, Disc gvr Loss: 0.188080
# Step 973: Generator Loss: 18.077534, Disc gvr Loss: 0.191145
# Step 974: Generator Loss: 16.909557, Disc gvr Loss: 0.281473
# Step 975: Generator Loss: 17.480326, Disc gvr Loss: 0.181869
# Step 976: Generator Loss: 17.428375, Disc gvr Loss: 0.153083
# Step 977: Generator Loss: 17.348082, Disc gvr Loss: 0.099382
# Step 978: Generator Loss: 17.072670, Disc gvr Loss: 0.069126
# Step 979: Generator Loss: 17.657204, Disc gvr Loss: 0.258749
# Step 980: Generator Loss: 17.840460, Disc gvr Loss: 0.494654
# Step 981: Generator Loss: 17.375374, Disc gvr Loss: 0.279448
# Step 982: Generator Loss: 17.576019, Disc gvr Loss: 0.152197
# Step 983: Generator Loss: 17.120567, Disc gvr Loss: 0.444300
# Step 984: Generator Loss: 17.978731, Disc gvr Loss: 0.069802
# Step 985: Generator Loss: 18.068157, Disc gvr Loss: 0.113425
# Step 986: Generator Loss: 18.065144, Disc gvr Loss: 0.086543
# Step 987: Generator Loss: 18.045738, Disc gvr Loss: 0.068052
# Step 988: Generator Loss: 17.909704, Disc gvr Loss: 0.081675
# Step 989: Generator Loss: 18.092632, Disc gvr Loss: 0.084411
# Step 990: Generator Loss: 18.088840, Disc gvr Loss: 0.068780
# Step 991: Generator Loss: 18.273067, Disc gvr Loss: 0.056807
# Step 992: Generator Loss: 18.075745, Disc gvr Loss: 0.083687
# Step 993: Generator Loss: 18.117342, Disc gvr Loss: 0.069621
# Step 994: Generator Loss: 18.065138, Disc gvr Loss: 0.072457
# Step 995: Generator Loss: 17.957256, Disc gvr Loss: 0.080533
# Step 996: Generator Loss: 17.900133, Disc gvr Loss: 0.052928
# Step 997: Generator Loss: 17.733810, Disc gvr Loss: 0.091730
# Step 998: Generator Loss: 18.241894, Disc gvr Loss: 0.076914
# Step 999: Generator Loss: 17.880926, Disc gvr Loss: 0.112044
# Step 1000: Generator Loss: 17.979601, Disc gvr Loss: 0.103734
# Starting actual training
# Step 1: Generator Loss: 18.067232, Disc SCI Loss: 2.291359, Disc gvr Loss: 0.067574
# Step 2: Generator Loss: 17.861717, Disc SCI Loss: 1.534516, Disc gvr Loss: 0.087224
# Step 3: Generator Loss: 18.311525, Disc SCI Loss: 1.423516, Disc gvr Loss: 0.058351
# Step 4: Generator Loss: 18.171955, Disc SCI Loss: 1.413703, Disc gvr Loss: 0.072426
# Step 5: Generator Loss: 18.163555, Disc SCI Loss: 1.371050, Disc gvr Loss: 0.059850
# Step 6: Generator Loss: 18.074806, Disc SCI Loss: 1.369662, Disc gvr Loss: 0.066225
# Step 7: Generator Loss: 17.725811, Disc SCI Loss: 1.421229, Disc gvr Loss: 0.099287
# Step 8: Generator Loss: 18.058714, Disc SCI Loss: 1.354814, Disc gvr Loss: 0.139509
# Step 9: Generator Loss: 18.042158, Disc SCI Loss: 1.351822, Disc gvr Loss: 0.070953
# Step 10: Generator Loss: 18.359438, Disc SCI Loss: 1.340703, Disc gvr Loss: 0.065495
# Finished Training
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4a32bcfe2440> in <module>
#      42     sess.run(iter_norm.initializer, feed_dict={ x_norm: X_test.todense()})
#      43     y_pred = sess.run(disc_SCI_normal)
# ---> 44     print(metrics.accuracy_score(y_test, y_pred))
#      45 #     # Generate images from noise, using the generator network.
#      46 #     f, a = plt.subplots(4, 10, figsize=(10, 4))
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# So we are getting a diverging GAN error, according to https://github.com/soumith/ganhacks/issues/14, this may be because
#
# Pretraining the generator with real susp conversations is not working since in training, noise is used as generator's input
